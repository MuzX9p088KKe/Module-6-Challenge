# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | nikolskoye
# Processing Record 3 of Set 1 | ongandjera
# Processing Record 4 of Set 1 | iqaluit
# Processing Record 5 of Set 1 | mwense
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 1 | georgetown
# Processing Record 10 of Set 1 | salisbury
# Processing Record 11 of Set 1 | puerto escondido
# Processing Record 12 of Set 1 | dikson
# Processing Record 13 of Set 1 | severo-kurilsk
# Processing Record 14 of Set 1 | souillac
# Processing Record 15 of Set 1 | haines junction
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | mahebourg
# Processing Record 18 of Set 1 | bethel
# Processing Record 19 of Set 1 | antofagasta
# Processing Record 20 of Set 1 | dalvik
# Processing Record 21 of Set 1 | beringovskiy
# Processing Record 22 of Set 1 | quang ngai
# Processing Record 23 of Set 1 | seydi
# Processing Record 24 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 1 | bezhanitsy
# Processing Record 26 of Set 1 | lagoa
# Processing Record 27 of Set 1 | toucheng
# Processing Record 28 of Set 1 | fomboni
# Processing Record 29 of Set 1 | iskateley
# Processing Record 30 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 1 | requena
# Processing Record 32 of Set 1 | flic en flac
# Processing Record 33 of Set 1 | pevek
# Processing Record 34 of Set 1 | bambous virieux
# Processing Record 35 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | gondar
# Processing Record 38 of Set 1 | puerto ayora
# Processing Record 39 of Set 1 | savannah bight
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | zavitinsk
# Processing Record 42 of Set 1 | camopi
# Processing Record 43 of Set 1 | vao
# Processing Record 44 of Set 1 | saint-augustin
# Processing Record 45 of Set 1 | coahuayana
# Processing Record 46 of Set 1 | portland
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | akdepe
# Processing Record 49 of Set 1 | sembakung
# Processing Record 50 of Set 1 | aykhal
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | barrow
# Processing Record 3 of Set 2 | menongue
# Processing Record 4 of Set 2 | torbay
# Processing Record 5 of Set 2 | sibut
# Processing Record 6 of Set 2 | kodiak
# Processing Record 7 of Set 2 | port lincoln
# Processing Record 8 of Set 2 | bengkulu
# Processing Record 9 of Set 2 | juxian
# City not found. Skipping...
# Processing Record 10 of Set 2 | tipuani
# Processing Record 11 of Set 2 | coihaique
# Processing Record 12 of Set 2 | hvide sande
# Processing Record 13 of Set 2 | ovsyanka
# Processing Record 14 of Set 2 | eremitu
# Processing Record 15 of Set 2 | new norfolk
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | tuatapere
# Processing Record 18 of Set 2 | rawson
# Processing Record 19 of Set 2 | muros
# Processing Record 20 of Set 2 | norman wells
# Processing Record 21 of Set 2 | jumla
# Processing Record 22 of Set 2 | bowen
# Processing Record 23 of Set 2 | sao filipe
# Processing Record 24 of Set 2 | nuevo progreso
# Processing Record 25 of Set 2 | itarema
# Processing Record 26 of Set 2 | lincoln
# Processing Record 27 of Set 2 | olinda
# Processing Record 28 of Set 2 | sao felix do xingu
# Processing Record 29 of Set 2 | tuktoyaktuk
# Processing Record 30 of Set 2 | sarangani
# Processing Record 31 of Set 2 | camacha
# Processing Record 32 of Set 2 | ampanihy
# Processing Record 33 of Set 2 | isangel
# Processing Record 34 of Set 2 | cape town
# Processing Record 35 of Set 2 | victoria
# Processing Record 36 of Set 2 | carnarvon
# Processing Record 37 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 38 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 2 | asau
# Processing Record 40 of Set 2 | pokhara
# Processing Record 41 of Set 2 | fortuna
# Processing Record 42 of Set 2 | katsuura
# Processing Record 43 of Set 2 | nelson
# Processing Record 44 of Set 2 | krasnoye
# Processing Record 45 of Set 2 | nyurba
# Processing Record 46 of Set 2 | xingyi
# Processing Record 47 of Set 2 | bonavista
# Processing Record 48 of Set 2 | arraial do cabo
# Processing Record 49 of Set 2 | puerto madero
# Processing Record 50 of Set 2 | itoman
# Processing Record 1 of Set 3 | tazovskiy
# Processing Record 2 of Set 3 | port alfred
# Processing Record 3 of Set 3 | airai
# Processing Record 4 of Set 3 | grand gaube
# Processing Record 5 of Set 3 | mar del plata
# Processing Record 6 of Set 3 | bluff
# Processing Record 7 of Set 3 | pisco
# Processing Record 8 of Set 3 | tateyama
# Processing Record 9 of Set 3 | salalah
# Processing Record 10 of Set 3 | ust-kuyga
# Processing Record 11 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 3 | lebu
# Processing Record 13 of Set 3 | east london
# Processing Record 14 of Set 3 | san cristobal
# Processing Record 15 of Set 3 | chumikan
# Processing Record 16 of Set 3 | avarua
# Processing Record 17 of Set 3 | kilingi-nomme
# Processing Record 18 of Set 3 | shakhovskaya
# Processing Record 19 of Set 3 | guilin
# Processing Record 20 of Set 3 | chokurdakh
# Processing Record 21 of Set 3 | faanui
# Processing Record 22 of Set 3 | ballina
# Processing Record 23 of Set 3 | kruisfontein
# Processing Record 24 of Set 3 | ribeira grande
# Processing Record 25 of Set 3 | silleda
# Processing Record 26 of Set 3 | iquitos
# Processing Record 27 of Set 3 | emirdag
# Processing Record 28 of Set 3 | rikitea
# Processing Record 29 of Set 3 | atuona
# Processing Record 30 of Set 3 | siteki
# Processing Record 31 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 32 of Set 3 | kristiansund
# Processing Record 33 of Set 3 | waingapu
# Processing Record 34 of Set 3 | jamestown
# Processing Record 35 of Set 3 | honiara
# Processing Record 36 of Set 3 | khatanga
# Processing Record 37 of Set 3 | poum
# Processing Record 38 of Set 3 | tarnos
# Processing Record 39 of Set 3 | gat
# Processing Record 40 of Set 3 | pushkino
# Processing Record 41 of Set 3 | clyde river
# Processing Record 42 of Set 3 | sao pedro do sul
# Processing Record 43 of Set 3 | ugoofaaru
# Processing Record 44 of Set 3 | usinsk
# Processing Record 45 of Set 3 | conde
# Processing Record 46 of Set 3 | chuy
# Processing Record 47 of Set 3 | plettenberg bay
# Processing Record 48 of Set 3 | taoudenni
# Processing Record 49 of Set 3 | shenzhen
# Processing Record 50 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 4 | dubna
# Processing Record 2 of Set 4 | ahualulco
# Processing Record 3 of Set 4 | andenes
# Processing Record 4 of Set 4 | ossora
# Processing Record 5 of Set 4 | kapaa
# Processing Record 6 of Set 4 | flinders
# Processing Record 7 of Set 4 | chapais
# Processing Record 8 of Set 4 | te anau
# Processing Record 9 of Set 4 | tautira
# Processing Record 10 of Set 4 | tasiilaq
# Processing Record 11 of Set 4 | nara
# Processing Record 12 of Set 4 | ruthin
# Processing Record 13 of Set 4 | juneau
# Processing Record 14 of Set 4 | dwarka
# Processing Record 15 of Set 4 | port hardy
# Processing Record 16 of Set 4 | sanandrei
# Processing Record 17 of Set 4 | saint-philippe
# Processing Record 18 of Set 4 | hobart
# Processing Record 19 of Set 4 | sorsk
# Processing Record 20 of Set 4 | thunder bay
# Processing Record 21 of Set 4 | yulara
# Processing Record 22 of Set 4 | hilo
# Processing Record 23 of Set 4 | hasaki
# Processing Record 24 of Set 4 | maceio
# Processing Record 25 of Set 4 | chikoy
# City not found. Skipping...
# Processing Record 26 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 27 of Set 4 | hamilton
# Processing Record 28 of Set 4 | namibe
# Processing Record 29 of Set 4 | tiksi
# Processing Record 30 of Set 4 | nuuk
# Processing Record 31 of Set 4 | cidreira
# Processing Record 32 of Set 4 | bairiki
# Processing Record 33 of Set 4 | bardsir
# Processing Record 34 of Set 4 | riyadh
# Processing Record 35 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 4 | castro
# Processing Record 37 of Set 4 | chernyy yar
# Processing Record 38 of Set 4 | egvekinot
# Processing Record 39 of Set 4 | santa cruz de la palma
# Processing Record 40 of Set 4 | noumea
# Processing Record 41 of Set 4 | jacobabad
# Processing Record 42 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 4 | ostrovnoy
# Processing Record 44 of Set 4 | shatrovo
# Processing Record 45 of Set 4 | sandnessjoen
# Processing Record 46 of Set 4 | camaqua
# Processing Record 47 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 4 | grande riviere du nord
# Processing Record 49 of Set 4 | mezen
# Processing Record 50 of Set 4 | yar-sale
# Processing Record 1 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 5 | upington
# Processing Record 3 of Set 5 | nouadhibou
# Processing Record 4 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 5 | khasan
# Processing Record 6 of Set 5 | baglung
# Processing Record 7 of Set 5 | vestmannaeyjar
# Processing Record 8 of Set 5 | vana-vigala
# Processing Record 9 of Set 5 | kalmunai
# Processing Record 10 of Set 5 | sovetskaya gavan
# Processing Record 11 of Set 5 | meulaboh
# Processing Record 12 of Set 5 | tura
# Processing Record 13 of Set 5 | kamenka
# Processing Record 14 of Set 5 | krasnozerskoye
# Processing Record 15 of Set 5 | lieksa
# Processing Record 16 of Set 5 | waddan
# Processing Record 17 of Set 5 | mount gambier
# Processing Record 18 of Set 5 | butaritari
# Processing Record 19 of Set 5 | imbituba
# Processing Record 20 of Set 5 | paray-le-monial
# Processing Record 21 of Set 5 | scottsburgh
# City not found. Skipping...
# Processing Record 22 of Set 5 | esperance
# Processing Record 23 of Set 5 | padang
# Processing Record 24 of Set 5 | sokoto
# Processing Record 25 of Set 5 | pokrovsk
# Processing Record 26 of Set 5 | havoysund
# Processing Record 27 of Set 5 | hasama
# City not found. Skipping...
# Processing Record 28 of Set 5 | istanbul
# Processing Record 29 of Set 5 | san quintin
# Processing Record 30 of Set 5 | tromso
# Processing Record 31 of Set 5 | aklavik
# Processing Record 32 of Set 5 | agirish
# Processing Record 33 of Set 5 | dehloran
# Processing Record 34 of Set 5 | sioux lookout
# Processing Record 35 of Set 5 | clonakilty
# Processing Record 36 of Set 5 | progreso
# Processing Record 37 of Set 5 | coolum beach
# Processing Record 38 of Set 5 | alexandria
# Processing Record 39 of Set 5 | zolotinka
# City not found. Skipping...
# Processing Record 40 of Set 5 | moroto
# Processing Record 41 of Set 5 | nosy varika
# Processing Record 42 of Set 5 | krasnoselkup
# Processing Record 43 of Set 5 | puerto leguizamo
# Processing Record 44 of Set 5 | cherskiy
# Processing Record 45 of Set 5 | magadan
# Processing Record 46 of Set 5 | bitam
# Processing Record 47 of Set 5 | alofi
# Processing Record 48 of Set 5 | pitimbu
# Processing Record 49 of Set 5 | gobabis
# Processing Record 50 of Set 5 | oktyabrskiy
# Processing Record 1 of Set 6 | upernavik
# Processing Record 2 of Set 6 | namatanai
# Processing Record 3 of Set 6 | le moule
# Processing Record 4 of Set 6 | vysokogornyy
# Processing Record 5 of Set 6 | bilma
# Processing Record 6 of Set 6 | big rapids
# Processing Record 7 of Set 6 | shahrud
# Processing Record 8 of Set 6 | oda
# Processing Record 9 of Set 6 | beloha
# Processing Record 10 of Set 6 | vallenar
# Processing Record 11 of Set 6 | thompson
# Processing Record 12 of Set 6 | oyama
# Processing Record 13 of Set 6 | caravelas
# Processing Record 14 of Set 6 | kamalapuram
# Processing Record 15 of Set 6 | shibukawa
# Processing Record 16 of Set 6 | the valley
# Processing Record 17 of Set 6 | roald
# Processing Record 18 of Set 6 | udachnyy
# Processing Record 19 of Set 6 | skibbereen
# Processing Record 20 of Set 6 | kavaratti
# Processing Record 21 of Set 6 | petkovci
# Processing Record 22 of Set 6 | botwood
# Processing Record 23 of Set 6 | tucuman
# Processing Record 24 of Set 6 | kaitangata
# Processing Record 25 of Set 6 | coquimbo
# Processing Record 26 of Set 6 | ambon
# Processing Record 27 of Set 6 | tual
# Processing Record 28 of Set 6 | hofn
# Processing Record 29 of Set 6 | paucartambo
# City not found. Skipping...
# Processing Record 30 of Set 6 | talnakh
# Processing Record 31 of Set 6 | leningradskiy
# Processing Record 32 of Set 6 | asmar
# Processing Record 33 of Set 6 | pangnirtung
# Processing Record 34 of Set 6 | tazlar
# Processing Record 35 of Set 6 | sheregesh
# Processing Record 36 of Set 6 | mackenzie
# Processing Record 37 of Set 6 | burica
# City not found. Skipping...
# Processing Record 38 of Set 6 | emba
# Processing Record 39 of Set 6 | nanortalik
# Processing Record 40 of Set 6 | mana
# Processing Record 41 of Set 6 | bourges
# Processing Record 42 of Set 6 | athabasca
# Processing Record 43 of Set 6 | provideniya
# Processing Record 44 of Set 6 | bambanglipuro
# Processing Record 45 of Set 6 | jacareacanga
# Processing Record 46 of Set 6 | maragogi
# Processing Record 47 of Set 6 | grindavik
# Processing Record 48 of Set 6 | fairbanks
# Processing Record 49 of Set 6 | graaff-reinet
# Processing Record 50 of Set 6 | bud
# Processing Record 1 of Set 7 | lasa
# Processing Record 2 of Set 7 | kidal
# Processing Record 3 of Set 7 | qinhuangdao
# Processing Record 4 of Set 7 | komsomolskiy
# Processing Record 5 of Set 7 | birobidzhan
# Processing Record 6 of Set 7 | port elizabeth
# Processing Record 7 of Set 7 | shumskiy
# Processing Record 8 of Set 7 | esil
# Processing Record 9 of Set 7 | batangafo
# Processing Record 10 of Set 7 | naryan-mar
# Processing Record 11 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 7 | luganville
# Processing Record 14 of Set 7 | fort nelson
# Processing Record 15 of Set 7 | zheleznodorozhnyy
# Processing Record 16 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 17 of Set 7 | lompoc
# Processing Record 18 of Set 7 | mehamn
# Processing Record 19 of Set 7 | yining
# Processing Record 20 of Set 7 | nome
# Processing Record 21 of Set 7 | bantry
# Processing Record 22 of Set 7 | saint george
# Processing Record 23 of Set 7 | qaanaaq
# Processing Record 24 of Set 7 | evensk
# Processing Record 25 of Set 7 | hithadhoo
# Processing Record 26 of Set 7 | celestun
# Processing Record 27 of Set 7 | verkhnyaya inta
# Processing Record 28 of Set 7 | rondonopolis
# Processing Record 29 of Set 7 | sungaipenuh
# Processing Record 30 of Set 7 | port hedland
# Processing Record 31 of Set 7 | pataias
# Processing Record 32 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 7 | cabo san lucas
# Processing Record 34 of Set 7 | walvis bay
# Processing Record 35 of Set 7 | matara
# Processing Record 36 of Set 7 | quelimane
# Processing Record 37 of Set 7 | muttupet
# Processing Record 38 of Set 7 | codrington
# Processing Record 39 of Set 7 | igbo ora
# Processing Record 40 of Set 7 | peniche
# Processing Record 41 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 42 of Set 7 | flin flon
# Processing Record 43 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 7 | linxia
# Processing Record 45 of Set 7 | bousse
# Processing Record 46 of Set 7 | carballo
# Processing Record 47 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 48 of Set 7 | vardo
# Processing Record 49 of Set 7 | mocuba
# Processing Record 50 of Set 7 | serra
# Processing Record 1 of Set 8 | kazachinskoye
# Processing Record 2 of Set 8 | vila velha
# Processing Record 3 of Set 8 | lerwick
# Processing Record 4 of Set 8 | russell
# Processing Record 5 of Set 8 | lokosovo
# Processing Record 6 of Set 8 | petatlan
# Processing Record 7 of Set 8 | fukue
# Processing Record 8 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 9 of Set 8 | bure
# Processing Record 10 of Set 8 | hobyo
# Processing Record 11 of Set 8 | den helder
# Processing Record 12 of Set 8 | tall kayf
# Processing Record 13 of Set 8 | ternate
# Processing Record 14 of Set 8 | port blair
# Processing Record 15 of Set 8 | denia
# Processing Record 16 of Set 8 | huarmey
# Processing Record 17 of Set 8 | raudeberg
# Processing Record 18 of Set 8 | college
# Processing Record 19 of Set 8 | dingle
# Processing Record 20 of Set 8 | yashkul
# Processing Record 21 of Set 8 | kununurra
# Processing Record 22 of Set 8 | deputatskiy
# Processing Record 23 of Set 8 | san jose
# Processing Record 24 of Set 8 | sol-iletsk
# Processing Record 25 of Set 8 | maykain
# City not found. Skipping...
# Processing Record 26 of Set 8 | danilov
# Processing Record 27 of Set 8 | pacific grove
# Processing Record 28 of Set 8 | faya
# Processing Record 29 of Set 8 | chokwe
# Processing Record 30 of Set 8 | ligayan
# Processing Record 31 of Set 8 | san patricio
# Processing Record 32 of Set 8 | hohhot
# Processing Record 33 of Set 8 | otaki
# Processing Record 34 of Set 8 | hisor
# Processing Record 35 of Set 8 | ganzhou
# Processing Record 36 of Set 8 | los llanos de aridane
# Processing Record 37 of Set 8 | dauphin
# Processing Record 38 of Set 8 | burnie
# Processing Record 39 of Set 8 | barkly west
# Processing Record 40 of Set 8 | umm kaddadah
# Processing Record 41 of Set 8 | sterling
# Processing Record 42 of Set 8 | alice springs
# Processing Record 43 of Set 8 | tabou
# Processing Record 44 of Set 8 | turayf
# Processing Record 45 of Set 8 | emilio carranza
# Processing Record 46 of Set 8 | surt
# Processing Record 47 of Set 8 | rio grande
# Processing Record 48 of Set 8 | newport
# Processing Record 49 of Set 8 | watsa
# Processing Record 50 of Set 8 | hatillo
# Processing Record 1 of Set 9 | ponta do sol
# Processing Record 2 of Set 9 | alangayam
# Processing Record 3 of Set 9 | canmore
# Processing Record 4 of Set 9 | dunedin
# Processing Record 5 of Set 9 | santa rosa
# Processing Record 6 of Set 9 | gushi
# Processing Record 7 of Set 9 | thohoyandou
# Processing Record 8 of Set 9 | muroto
# Processing Record 9 of Set 9 | ituporanga
# Processing Record 10 of Set 9 | nioro
# Processing Record 11 of Set 9 | sinjar
# Processing Record 12 of Set 9 | geraldton
# Processing Record 13 of Set 9 | balaguer
# Processing Record 14 of Set 9 | ridgetown
# Processing Record 15 of Set 9 | cayenne
# Processing Record 16 of Set 9 | gubkinskiy
# Processing Record 17 of Set 9 | longyearbyen
# Processing Record 18 of Set 9 | kailua
# Processing Record 19 of Set 9 | eydhafushi
# Processing Record 20 of Set 9 | sulina
# Processing Record 21 of Set 9 | westport
# Processing Record 22 of Set 9 | kodinsk
# Processing Record 23 of Set 9 | el tigre
# Processing Record 24 of Set 9 | najran
# Processing Record 25 of Set 9 | grojec
# Processing Record 26 of Set 9 | hamada
# Processing Record 27 of Set 9 | sinor
# Processing Record 28 of Set 9 | bahia blanca
# Processing Record 29 of Set 9 | xingcheng
# Processing Record 30 of Set 9 | ferrol
# Processing Record 31 of Set 9 | chalmette
# Processing Record 32 of Set 9 | fare
# Processing Record 33 of Set 9 | sorland
# Processing Record 34 of Set 9 | illapel
# Processing Record 35 of Set 9 | sur
# Processing Record 36 of Set 9 | cururupu
# Processing Record 37 of Set 9 | loiza
# Processing Record 38 of Set 9 | plainview
# Processing Record 39 of Set 9 | solnechnyy
# Processing Record 40 of Set 9 | pudozh
# Processing Record 41 of Set 9 | quatre cocos
# Processing Record 42 of Set 9 | batticaloa
# Processing Record 43 of Set 9 | shu
# Processing Record 44 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 45 of Set 9 | sumenep
# Processing Record 46 of Set 9 | dali
# Processing Record 47 of Set 9 | baruun-urt
# Processing Record 48 of Set 9 | west wendover
# Processing Record 49 of Set 9 | aksarka
# Processing Record 50 of Set 9 | shelburne
# Processing Record 1 of Set 10 | acopiara
# Processing Record 2 of Set 10 | berlevag
# Processing Record 3 of Set 10 | sitka
# Processing Record 4 of Set 10 | bacsalmas
# Processing Record 5 of Set 10 | san jeronimo
# Processing Record 6 of Set 10 | ojinaga
# Processing Record 7 of Set 10 | tommot
# Processing Record 8 of Set 10 | karakol
# Processing Record 9 of Set 10 | cairns
# Processing Record 10 of Set 10 | abiy adi
# City not found. Skipping...
# Processing Record 11 of Set 10 | palembang
# Processing Record 12 of Set 10 | saskylakh
# Processing Record 13 of Set 10 | praia da vitoria
# Processing Record 14 of Set 10 | tuburan
# Processing Record 15 of Set 10 | rio bananal
# Processing Record 16 of Set 10 | lismore
# Processing Record 17 of Set 10 | san vicente
# Processing Record 18 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 10 | avera
# Processing Record 20 of Set 10 | enshi
# Processing Record 21 of Set 10 | baoshan
# Processing Record 22 of Set 10 | marietta
# Processing Record 23 of Set 10 | tilichiki
# Processing Record 24 of Set 10 | prince rupert
# Processing Record 25 of Set 10 | kafue
# Processing Record 26 of Set 10 | jiuquan
# Processing Record 27 of Set 10 | hambantota
# Processing Record 28 of Set 10 | billings
# Processing Record 29 of Set 10 | gairo
# Processing Record 30 of Set 10 | atar
# Processing Record 31 of Set 10 | kavieng
# Processing Record 32 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 33 of Set 10 | abu samrah
# Processing Record 34 of Set 10 | takoradi
# Processing Record 35 of Set 10 | guhagar
# Processing Record 36 of Set 10 | montmagny
# Processing Record 37 of Set 10 | colac
# Processing Record 38 of Set 10 | hellin
# Processing Record 39 of Set 10 | necochea
# Processing Record 40 of Set 10 | cabedelo
# Processing Record 41 of Set 10 | ahipara
# Processing Record 42 of Set 10 | shakawe
# Processing Record 43 of Set 10 | santa isabel do rio negro
# Processing Record 44 of Set 10 | batagay-alyta
# Processing Record 45 of Set 10 | capanema
# Processing Record 46 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 47 of Set 10 | marzuq
# Processing Record 48 of Set 10 | texistepeque
# Processing Record 49 of Set 10 | zamosc
# Processing Record 50 of Set 10 | tubruq
# City not found. Skipping...
# Processing Record 1 of Set 11 | naze
# Processing Record 2 of Set 11 | gizo
# Processing Record 3 of Set 11 | verkhoturye
# Processing Record 4 of Set 11 | la tuque
# Processing Record 5 of Set 11 | dzhebariki-khaya
# Processing Record 6 of Set 11 | saldanha
# Processing Record 7 of Set 11 | bogovarovo
# Processing Record 8 of Set 11 | ilhabela
# Processing Record 9 of Set 11 | pershotravneve
# Processing Record 10 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 11 of Set 11 | sicamous
# Processing Record 12 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 13 of Set 11 | betioky
# Processing Record 14 of Set 11 | ballyhaunis
# Processing Record 15 of Set 11 | yaan
# Processing Record 16 of Set 11 | lavrentiya
# Processing Record 17 of Set 11 | ilulissat
# Processing Record 18 of Set 11 | galgani
# City not found. Skipping...
# Processing Record 19 of Set 11 | nanga eboko
# Processing Record 20 of Set 11 | tir pol
# City not found. Skipping...
# Processing Record 21 of Set 11 | guerrero negro
# Processing Record 22 of Set 11 | suntar
# Processing Record 23 of Set 11 | carora
# Processing Record 24 of Set 11 | campagna
# Processing Record 25 of Set 11 | grushevskaya
# Processing Record 26 of Set 11 | zaraza
# Processing Record 27 of Set 11 | mikhaylovka
# Processing Record 28 of Set 11 | sola
# Processing Record 29 of Set 11 | kushiro
# Processing Record 30 of Set 11 | port macquarie
# Processing Record 31 of Set 11 | shubarshi
# Processing Record 32 of Set 11 | mabaruma
# Processing Record 33 of Set 11 | gemena
# Processing Record 34 of Set 11 | ankazobe
# Processing Record 35 of Set 11 | duncan
# Processing Record 36 of Set 11 | yuryevets
# Processing Record 37 of Set 11 | abay
# Processing Record 38 of Set 11 | vila franca do campo
# Processing Record 39 of Set 11 | edd
# Processing Record 40 of Set 11 | bathsheba
# Processing Record 41 of Set 11 | tanete
# Processing Record 42 of Set 11 | chaoyang
# Processing Record 43 of Set 11 | raichur
# Processing Record 44 of Set 11 | mataram
# Processing Record 45 of Set 11 | agadir
# Processing Record 46 of Set 11 | xiangxiang
# Processing Record 47 of Set 11 | sangar
# Processing Record 48 of Set 11 | powell
# Processing Record 49 of Set 11 | san fernando
# Processing Record 50 of Set 11 | nanning
# Processing Record 1 of Set 12 | sioux falls
# Processing Record 2 of Set 12 | kloulklubed
# Processing Record 3 of Set 12 | sambava
# Processing Record 4 of Set 12 | chara
# Processing Record 5 of Set 12 | benjamin constant
# Processing Record 6 of Set 12 | clifton
# Processing Record 7 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 8 of Set 12 | besancon
# Processing Record 9 of Set 12 | kirovskaya
# Processing Record 10 of Set 12 | lar
# Processing Record 11 of Set 12 | sulya
# Processing Record 12 of Set 12 | bonnyville
# Processing Record 13 of Set 12 | inirida
# Processing Record 14 of Set 12 | smithers
# Processing Record 15 of Set 12 | selikhino
# Processing Record 16 of Set 12 | syracuse
# Processing Record 17 of Set 12 | aquiraz
# Processing Record 18 of Set 12 | gualaquiza
# Processing Record 19 of Set 12 | sovetsk
# Processing Record 20 of Set 12 | simao
# Processing Record 21 of Set 12 | kerki
# City not found. Skipping...
# Processing Record 22 of Set 12 | luderitz
# Processing Record 23 of Set 12 | pierre
# Processing Record 24 of Set 12 | cockburn town
# Processing Record 25 of Set 12 | brae
# Processing Record 26 of Set 12 | barranca
# Processing Record 27 of Set 12 | maxixe
# Processing Record 28 of Set 12 | nelson bay
# Processing Record 29 of Set 12 | abu zabad
# Processing Record 30 of Set 12 | barreirinha
# Processing Record 31 of Set 12 | kenora
# Processing Record 32 of Set 12 | jardim
# Processing Record 33 of Set 12 | shupiyan
# Processing Record 34 of Set 12 | blagoyevo
# Processing Record 35 of Set 12 | serov
# Processing Record 36 of Set 12 | benguela
# Processing Record 37 of Set 12 | terbuny
# Processing Record 38 of Set 12 | nantucket
# Processing Record 39 of Set 12 | minusinsk
# Processing Record 40 of Set 12 | placido de castro
# Processing Record 41 of Set 12 | ordu
# Processing Record 42 of Set 12 | zharkent
# Processing Record 43 of Set 12 | diu
# Processing Record 44 of Set 12 | kudahuvadhoo
# Processing Record 45 of Set 12 | benito juarez
# Processing Record 46 of Set 12 | sjenica
# Processing Record 47 of Set 12 | wickede
# Processing Record 48 of Set 12 | mazagao
# Processing Record 49 of Set 12 | karratha
# Processing Record 50 of Set 12 | denpasar
# Processing Record 1 of Set 13 | boda
# Processing Record 2 of Set 13 | laguna
# Processing Record 3 of Set 13 | degollado
# Processing Record 4 of Set 13 | kapiri mposhi
# Processing Record 5 of Set 13 | veinticinco de mayo
# Processing Record 6 of Set 13 | platanos
# Processing Record 7 of Set 13 | gondanglegi
# Processing Record 8 of Set 13 | saint anthony
# Processing Record 9 of Set 13 | saint-joseph
# Processing Record 10 of Set 13 | shingu
# Processing Record 11 of Set 13 | narsaq
# Processing Record 12 of Set 13 | podyuga
# Processing Record 13 of Set 13 | micoud
# Processing Record 14 of Set 13 | trinidad
# Processing Record 15 of Set 13 | sabha
# Processing Record 16 of Set 13 | xirokambion
# City not found. Skipping...
# Processing Record 17 of Set 13 | asfi
# Processing Record 18 of Set 13 | tucumcari
# Processing Record 19 of Set 13 | arman
# Processing Record 20 of Set 13 | khomeyn
# Processing Record 21 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 22 of Set 13 | salamiyah
# Processing Record 23 of Set 13 | rudnogorsk
# Processing Record 24 of Set 13 | malumfashi
# Processing Record 25 of Set 13 | vangaindrano
# Processing Record 26 of Set 13 | arys
# Processing Record 27 of Set 13 | bukama
# Processing Record 28 of Set 13 | hendersonville
# Processing Record 29 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 30 of Set 13 | teahupoo
# Processing Record 31 of Set 13 | turukhansk
# Processing Record 32 of Set 13 | ayorou
# Processing Record 33 of Set 13 | bonthe
# Processing Record 34 of Set 13 | zhigansk
# Processing Record 35 of Set 13 | christchurch
# Processing Record 36 of Set 13 | kanasin
# Processing Record 37 of Set 13 | abu kamal
# Processing Record 38 of Set 13 | niamey
# Processing Record 39 of Set 13 | shahpur
# Processing Record 40 of Set 13 | battle creek
# Processing Record 41 of Set 13 | floro
# Processing Record 42 of Set 13 | touros
# Processing Record 43 of Set 13 | lanzhou
# Processing Record 44 of Set 13 | bartica
# Processing Record 45 of Set 13 | gwanda
# Processing Record 46 of Set 13 | rabaul
# Processing Record 47 of Set 13 | jabinyanah
# Processing Record 48 of Set 13 | nemuro
# Processing Record 49 of Set 13 | bereda
# Processing Record 50 of Set 13 | rocha
# Processing Record 1 of Set 14 | porto santo
# Processing Record 2 of Set 14 | nizhnyaya tavda
# Processing Record 3 of Set 14 | port alberni
# Processing Record 4 of Set 14 | glace bay
# Processing Record 5 of Set 14 | kholmogory
# Processing Record 6 of Set 14 | bababe
# City not found. Skipping...
# Processing Record 7 of Set 14 | condega
# Processing Record 8 of Set 14 | bossangoa
# Processing Record 9 of Set 14 | lorengau
# Processing Record 10 of Set 14 | phuket
# Processing Record 11 of Set 14 | sao joao da barra
# Processing Record 12 of Set 14 | nagapattinam
# Processing Record 13 of Set 14 | bam
# Processing Record 14 of Set 14 | nabire
# Processing Record 15 of Set 14 | nisia floresta
# Processing Record 16 of Set 14 | pontian kecil
# Processing Record 17 of Set 14 | romitan
# Processing Record 18 of Set 14 | little current
# Processing Record 19 of Set 14 | oga
# Processing Record 20 of Set 14 | buala
# Processing Record 21 of Set 14 | murgab
# Processing Record 22 of Set 14 | atambua
# Processing Record 23 of Set 14 | salinopolis
# Processing Record 24 of Set 14 | koslan
# Processing Record 25 of Set 14 | zlitan
# Processing Record 26 of Set 14 | saint-georges
# Processing Record 27 of Set 14 | kabare
# Processing Record 28 of Set 14 | zlobin
# Processing Record 29 of Set 14 | santa marinella
# Processing Record 30 of Set 14 | tigil
# Processing Record 31 of Set 14 | kieta
# Processing Record 32 of Set 14 | batesville
# Processing Record 33 of Set 14 | ajdabiya
# Processing Record 34 of Set 14 | port-gentil
# Processing Record 35 of Set 14 | goure
# Processing Record 36 of Set 14 | nichinan
# Processing Record 37 of Set 14 | thinadhoo
# Processing Record 38 of Set 14 | zhukovka
# Processing Record 39 of Set 14 | palmer
# Processing Record 40 of Set 14 | akcaabat
# Processing Record 41 of Set 14 | batemans bay
# Processing Record 42 of Set 14 | cacule
# Processing Record 43 of Set 14 | axim
# Processing Record 44 of Set 14 | banda aceh
# Processing Record 45 of Set 14 | bouca
# Processing Record 46 of Set 14 | mantua
# Processing Record 47 of Set 14 | kuching
# Processing Record 48 of Set 14 | uvira
# Processing Record 49 of Set 14 | dhidhdhoo
# Processing Record 50 of Set 14 | kiunga
# Processing Record 1 of Set 15 | middlebury
# Processing Record 2 of Set 15 | zhigalovo
# Processing Record 3 of Set 15 | ketchikan
# Processing Record 4 of Set 15 | siilinjarvi
# Processing Record 5 of Set 15 | aasiaat
# Processing Record 6 of Set 15 | constitucion
# Processing Record 7 of Set 15 | wewak
# Processing Record 8 of Set 15 | viisoara
# Processing Record 9 of Set 15 | hachinohe
# Processing Record 10 of Set 15 | korla
# Processing Record 11 of Set 15 | pincher creek
# Processing Record 12 of Set 15 | mugur-aksy
# Processing Record 13 of Set 15 | fuxin
# Processing Record 14 of Set 15 | yurla
# Processing Record 15 of Set 15 | tsogni
# Processing Record 16 of Set 15 | varkaus
# Processing Record 17 of Set 15 | mercedes
# Processing Record 18 of Set 15 | general pico
# Processing Record 19 of Set 15 | lalomanu
# City not found. Skipping...
# Processing Record 20 of Set 15 | monatele
# City not found. Skipping...
# Processing Record 21 of Set 15 | zaysan
# Processing Record 22 of Set 15 | pontes e lacerda
# Processing Record 23 of Set 15 | lisakovsk
# Processing Record 24 of Set 15 | nador
# Processing Record 25 of Set 15 | tarakan
# Processing Record 26 of Set 15 | guinope
# Processing Record 27 of Set 15 | marmaris
# Processing Record 28 of Set 15 | gorom-gorom
# Processing Record 29 of Set 15 | saint-louis
# Processing Record 30 of Set 15 | sayyan
# Processing Record 31 of Set 15 | amapa
# Processing Record 32 of Set 15 | natal
# Processing Record 33 of Set 15 | williamsport
# Processing Record 34 of Set 15 | mogok
# Processing Record 35 of Set 15 | koumac
# Processing Record 36 of Set 15 | kothi
# Processing Record 37 of Set 15 | buraydah
# Processing Record 38 of Set 15 | kutum
# Processing Record 39 of Set 15 | lafiagi
# Processing Record 40 of Set 15 | moron
# Processing Record 41 of Set 15 | manzanillo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check data
city_data
# Out:
# [{'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 57.04,
#   'Humidity': 74,
#   'Cloudiness': 23,
#   'Wind Speed': 11.65,
#   'Country': 'AU',
#   'Date': '2021-06-05 14:03:25',
#   'Current Description': 'few clouds'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 78.69,
#   'Humidity': 33,
#   'Cloudiness': 88,
#   'Wind Speed': 1.19,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:03:25',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ongandjera',
#   'Lat': -17.8833,
#   'Lng': 15.0667,
#   'Max Temp': 76.42,
#   'Humidity': 16,
#   'Cloudiness': 0,
#   'Wind Speed': 9.62,
#   'Country': 'NA',
#   'Date': '2021-06-05 14:03:26',
#   'Current Description': 'clear sky'},
#  {'City': 'Iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 31.69,
#   'Humidity': 89,
#   'Cloudiness': 99,
#   'Wind Speed': 8.01,
#   'Country': 'CA',
#   'Date': '2021-06-05 14:03:26',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mwense',
#   'Lat': -10.3845,
#   'Lng': 28.698,
#   'Max Temp': 77.65,
#   'Humidity': 45,
#   'Cloudiness': 100,
#   'Wind Speed': 7.52,
#   'Country': 'ZM',
#   'Date': '2021-06-05 14:03:27',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 57.33,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 7.83,
#   'Country': 'CA',
#   'Date': '2021-06-05 14:03:27',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 79.75,
#   'Humidity': 73,
#   'Cloudiness': 9,
#   'Wind Speed': 8.52,
#   'Country': 'US',
#   'Date': '2021-06-05 14:03:27',
#   'Current Description': 'clear sky'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 80.89,
#   'Humidity': 89,
#   'Cloudiness': 20,
#   'Wind Speed': 2.77,
#   'Country': 'MY',
#   'Date': '2021-06-05 14:03:28',
#   'Current Description': 'moderate rain'},
#  {'City': 'Salisbury',
#   'Lat': 51.0693,
#   'Lng': -1.7957,
#   'Max Temp': 72.68,
#   'Humidity': 48,
#   'Cloudiness': 21,
#   'Wind Speed': 7.43,
#   'Country': 'GB',
#   'Date': '2021-06-05 14:02:34',
#   'Current Description': 'few clouds'},
#  {'City': 'Puerto Escondido',
#   'Lat': 15.85,
#   'Lng': -97.0667,
#   'Max Temp': 83.44,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 1.5,
#   'Country': 'MX',
#   'Date': '2021-06-05 14:03:28',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 30.97,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 13.42,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:03:29',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 41.56,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 25.99,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:03:29',
#   'Current Description': 'moderate rain'},
#  {'City': 'Souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 75.36,
#   'Humidity': 75,
#   'Cloudiness': 47,
#   'Wind Speed': 9.22,
#   'Country': 'MU',
#   'Date': '2021-06-05 14:03:29',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Haines Junction',
#   'Lat': 60.7522,
#   'Lng': -137.5108,
#   'Max Temp': 45.7,
#   'Humidity': 83,
#   'Cloudiness': 86,
#   'Wind Speed': 3.33,
#   'Country': 'CA',
#   'Date': '2021-06-05 14:03:30',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 73.78,
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 14.67,
#   'Country': 'TO',
#   'Date': '2021-06-05 14:03:30',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 75.25,
#   'Humidity': 73,
#   'Cloudiness': 19,
#   'Wind Speed': 9.93,
#   'Country': 'MU',
#   'Date': '2021-06-05 14:03:30',
#   'Current Description': 'few clouds'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 81.88,
#   'Humidity': 75,
#   'Cloudiness': 35,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2021-06-05 14:03:31',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Antofagasta',
#   'Lat': -23.65,
#   'Lng': -70.4,
#   'Max Temp': 65.01,
#   'Humidity': 67,
#   'Cloudiness': 5,
#   'Wind Speed': 6.78,
#   'Country': 'CL',
#   'Date': '2021-06-05 14:02:28',
#   'Current Description': 'clear sky'},
#  {'City': 'Dalvik',
#   'Lat': 65.9702,
#   'Lng': -18.5286,
#   'Max Temp': 52.7,
#   'Humidity': 81,
#   'Cloudiness': 96,
#   'Wind Speed': 7.25,
#   'Country': 'IS',
#   'Date': '2021-06-05 14:03:31',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Beringovskiy',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': 39.67,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 7.87,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:03:32',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Quang Ngai',
#   'Lat': 15.1167,
#   'Lng': 108.8,
#   'Max Temp': 76.93,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 7.7,
#   'Country': 'VN',
#   'Date': '2021-06-05 14:02:32',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Seydi',
#   'Lat': 39.4816,
#   'Lng': 62.9137,
#   'Max Temp': 109.31,
#   'Humidity': 7,
#   'Cloudiness': 47,
#   'Wind Speed': 5.5,
#   'Country': 'TM',
#   'Date': '2021-06-05 14:03:32',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bezhanitsy',
#   'Lat': 56.9767,
#   'Lng': 29.8907,
#   'Max Temp': 70.97,
#   'Humidity': 50,
#   'Cloudiness': 100,
#   'Wind Speed': 4.16,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:03:33',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lagoa',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 62.58,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 1.86,
#   'Country': 'PT',
#   'Date': '2021-06-05 14:03:33',
#   'Current Description': 'clear sky'},
#  {'City': 'Toucheng',
#   'Lat': 24.8592,
#   'Lng': 121.8233,
#   'Max Temp': 80.15,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.57,
#   'Country': 'TW',
#   'Date': '2021-06-05 14:03:33',
#   'Current Description': 'light rain'},
#  {'City': 'Fomboni',
#   'Lat': -12.28,
#   'Lng': 43.7425,
#   'Max Temp': 79.86,
#   'Humidity': 73,
#   'Cloudiness': 79,
#   'Wind Speed': 22.44,
#   'Country': 'KM',
#   'Date': '2021-06-05 14:03:34',
#   'Current Description': 'light rain'},
#  {'City': 'Iskateley',
#   'Lat': 67.6803,
#   'Lng': 53.1512,
#   'Max Temp': 50.4,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 11.86,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:03:34',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Requena',
#   'Lat': 39.4883,
#   'Lng': -1.1004,
#   'Max Temp': 66.7,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 8.08,
#   'Country': 'ES',
#   'Date': '2021-06-05 14:03:35',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Flic En Flac',
#   'Lat': -20.2742,
#   'Lng': 57.3631,
#   'Max Temp': 75.52,
#   'Humidity': 73,
#   'Cloudiness': 11,
#   'Wind Speed': 10.51,
#   'Country': 'MU',
#   'Date': '2021-06-05 14:01:04',
#   'Current Description': 'few clouds'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': 40.86,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 8.88,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:03:35',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 75.22,
#   'Humidity': 73,
#   'Cloudiness': 18,
#   'Wind Speed': 9.6,
#   'Country': 'MU',
#   'Date': '2021-06-05 14:03:36',
#   'Current Description': 'few clouds'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 29.37,
#   'Humidity': 91,
#   'Cloudiness': 99,
#   'Wind Speed': 1.5,
#   'Country': 'AR',
#   'Date': '2021-06-05 14:00:01',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gondar',
#   'Lat': 12.6,
#   'Lng': 37.4667,
#   'Max Temp': 79.21,
#   'Humidity': 25,
#   'Cloudiness': 87,
#   'Wind Speed': 1.99,
#   'Country': 'ET',
#   'Date': '2021-06-05 14:03:36',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 74.55,
#   'Humidity': 87,
#   'Cloudiness': 98,
#   'Wind Speed': 5.01,
#   'Country': 'EC',
#   'Date': '2021-06-05 14:03:37',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Savannah Bight',
#   'Lat': 16.45,
#   'Lng': -85.85,
#   'Max Temp': 86,
#   'Humidity': 78,
#   'Cloudiness': 8,
#   'Wind Speed': 20.58,
#   'Country': 'HN',
#   'Date': '2021-06-05 14:03:37',
#   'Current Description': 'clear sky'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 35.11,
#   'Humidity': 93,
#   'Cloudiness': 28,
#   'Wind Speed': 7.81,
#   'Country': 'CL',
#   'Date': '2021-06-05 14:03:37',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Zavitinsk',
#   'Lat': 50.1167,
#   'Lng': 129.45,
#   'Max Temp': 50.16,
#   'Humidity': 91,
#   'Cloudiness': 94,
#   'Wind Speed': 3.27,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:03:38',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Camopi',
#   'Lat': 3.1655,
#   'Lng': -52.3158,
#   'Max Temp': 84.22,
#   'Humidity': 63,
#   'Cloudiness': 70,
#   'Wind Speed': 4.9,
#   'Country': 'GF',
#   'Date': '2021-06-05 14:03:38',
#   'Current Description': 'broken clouds'},
#  {'City': 'Vao',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 72.64,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 17.13,
#   'Country': 'NC',
#   'Date': '2021-06-05 14:03:38',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint-Augustin',
#   'Lat': 51.226,
#   'Lng': -58.6502,
#   'Max Temp': 49.86,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 10.16,
#   'Country': 'CA',
#   'Date': '2021-06-05 14:03:39',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Coahuayana',
#   'Lat': 18.7333,
#   'Lng': -103.6833,
#   'Max Temp': 83.73,
#   'Humidity': 62,
#   'Cloudiness': 99,
#   'Wind Speed': 0.54,
#   'Country': 'MX',
#   'Date': '2021-06-05 14:03:39',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Portland',
#   'Lat': 45.5234,
#   'Lng': -122.6762,
#   'Max Temp': 58.24,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Date': '2021-06-05 13:59:43',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 69.28,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 4.09,
#   'Country': 'ZA',
#   'Date': '2021-06-05 14:03:40',
#   'Current Description': 'clear sky'},
#  {'City': 'Akdepe',
#   'Lat': 42.0551,
#   'Lng': 59.3788,
#   'Max Temp': 100.4,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 18.61,
#   'Country': 'TM',
#   'Date': '2021-06-05 14:03:40',
#   'Current Description': 'clear sky'},
#  {'City': 'Sembakung',
#   'Lat': 3.8167,
#   'Lng': 117.25,
#   'Max Temp': 76.39,
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind Speed': 1.36,
#   'Country': 'ID',
#   'Date': '2021-06-05 14:03:40',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Aykhal',
#   'Lat': 66,
#   'Lng': 111.5,
#   'Max Temp': 43.23,
#   'Humidity': 55,
#   'Cloudiness': 31,
#   'Wind Speed': 13.78,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:03:41',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 49.48,
#   'Humidity': 95,
#   'Cloudiness': 64,
#   'Wind Speed': 2.15,
#   'Country': 'NZ',
#   'Date': '2021-06-05 14:03:42',
#   'Current Description': 'broken clouds'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 30.22,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Country': 'US',
#   'Date': '2021-06-05 14:03:42',
#   'Current Description': 'fog'},
#  {'City': 'Menongue',
#   'Lat': -14.6585,
#   'Lng': 17.691,
#   'Max Temp': 78.22,
#   'Humidity': 14,
#   'Cloudiness': 59,
#   'Wind Speed': 5.68,
#   'Country': 'AO',
#   'Date': '2021-06-05 14:03:42',
#   'Current Description': 'broken clouds'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 63.75,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'CA',
#   'Date': '2021-06-05 14:03:43',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sibut',
#   'Lat': 5.718,
#   'Lng': 19.0739,
#   'Max Temp': 77.88,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 2.17,
#   'Country': 'CF',
#   'Date': '2021-06-05 14:03:43',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 45.79,
#   'Humidity': 77,
#   'Cloudiness': 92,
#   'Wind Speed': 5.66,
#   'Country': 'US',
#   'Date': '2021-06-05 14:03:43',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Lincoln',
#   'Lat': -34.7333,
#   'Lng': 135.8667,
#   'Max Temp': 58.12,
#   'Humidity': 90,
#   'Cloudiness': 50,
#   'Wind Speed': 11.77,
#   'Country': 'AU',
#   'Date': '2021-06-05 14:03:44',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 77.05,
#   'Humidity': 90,
#   'Cloudiness': 20,
#   'Wind Speed': 3.78,
#   'Country': 'ID',
#   'Date': '2021-06-05 14:03:44',
#   'Current Description': 'few clouds'},
#  {'City': 'Tipuani',
#   'Lat': -15.5648,
#   'Lng': -68.0185,
#   'Max Temp': 76.42,
#   'Humidity': 76,
#   'Cloudiness': 82,
#   'Wind Speed': 1.61,
#   'Country': 'BO',
#   'Date': '2021-06-05 14:03:45',
#   'Current Description': 'broken clouds'},
#  {'City': 'Coihaique',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 39.42,
#   'Humidity': 88,
#   'Cloudiness': 89,
#   'Wind Speed': 6.91,
#   'Country': 'CL',
#   'Date': '2021-06-05 14:03:45',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hvide Sande',
#   'Lat': 56.0045,
#   'Lng': 8.1294,
#   'Max Temp': 73.98,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 8.16,
#   'Country': 'DK',
#   'Date': '2021-06-05 14:03:45',
#   'Current Description': 'clear sky'},
#  {'City': 'Ovsyanka',
#   'Lat': 55.9575,
#   'Lng': 92.5519,
#   'Max Temp': 54.57,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 4.41,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:03:46',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Eremitu',
#   'Lat': 46.6667,
#   'Lng': 24.9333,
#   'Max Temp': 72.3,
#   'Humidity': 77,
#   'Cloudiness': 93,
#   'Wind Speed': 8.72,
#   'Country': 'RO',
#   'Date': '2021-06-05 14:03:46',
#   'Current Description': 'overcast clouds'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 47.57,
#   'Humidity': 64,
#   'Cloudiness': 71,
#   'Wind Speed': 1.01,
#   'Country': 'AU',
#   'Date': '2021-06-05 14:03:46',
#   'Current Description': 'broken clouds'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 69.8,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 3.24,
#   'Country': 'ZA',
#   'Date': '2021-06-05 14:03:47',
#   'Current Description': 'clear sky'},
#  {'City': 'Tuatapere',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 49.82,
#   'Humidity': 90,
#   'Cloudiness': 7,
#   'Wind Speed': 3.4,
#   'Country': 'NZ',
#   'Date': '2021-06-05 14:03:47',
#   'Current Description': 'clear sky'},
#  {'City': 'Rawson',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 47.1,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 20.2,
#   'Country': 'AR',
#   'Date': '2021-06-05 14:03:47',
#   'Current Description': 'clear sky'},
#  {'City': 'Muros',
#   'Lat': 42.7762,
#   'Lng': -9.0603,
#   'Max Temp': 81.68,
#   'Humidity': 44,
#   'Cloudiness': 6,
#   'Wind Speed': 14.61,
#   'Country': 'ES',
#   'Date': '2021-06-05 14:03:48',
#   'Current Description': 'clear sky'},
#  {'City': 'Norman Wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 44.64,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'CA',
#   'Date': '2021-06-05 14:03:48',
#   'Current Description': 'light rain'},
#  {'City': 'Jumla',
#   'Lat': 29.2747,
#   'Lng': 82.1838,
#   'Max Temp': 59,
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 0.65,
#   'Country': 'NP',
#   'Date': '2021-06-05 14:03:49',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bowen',
#   'Lat': -20.0167,
#   'Lng': 148.2333,
#   'Max Temp': 59.67,
#   'Humidity': 72,
#   'Cloudiness': 55,
#   'Wind Speed': 7.83,
#   'Country': 'AU',
#   'Date': '2021-06-05 14:03:49',
#   'Current Description': 'broken clouds'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 78.01,
#   'Humidity': 64,
#   'Cloudiness': 4,
#   'Wind Speed': 10.2,
#   'Country': 'CV',
#   'Date': '2021-06-05 14:03:49',
#   'Current Description': 'clear sky'},
#  {'City': 'Nuevo Progreso',
#   'Lat': 23.1667,
#   'Lng': -97.95,
#   'Max Temp': 81.46,
#   'Humidity': 79,
#   'Cloudiness': 8,
#   'Wind Speed': 1.99,
#   'Country': 'MX',
#   'Date': '2021-06-05 14:03:50',
#   'Current Description': 'clear sky'},
#  {'City': 'Itarema',
#   'Lat': -2.9248,
#   'Lng': -39.9167,
#   'Max Temp': 86.4,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 13.04,
#   'Country': 'BR',
#   'Date': '2021-06-05 14:03:50',
#   'Current Description': 'clear sky'},
#  {'City': 'Lincoln',
#   'Lat': 40.8,
#   'Lng': -96.667,
#   'Max Temp': 78.24,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 5.01,
#   'Country': 'US',
#   'Date': '2021-06-05 14:00:04',
#   'Current Description': 'clear sky'},
#  {'City': 'Olinda',
#   'Lat': -8.0089,
#   'Lng': -34.8553,
#   'Max Temp': 80.33,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 11.27,
#   'Country': 'BR',
#   'Date': '2021-06-05 14:03:50',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sao Felix Do Xingu',
#   'Lat': -6.6447,
#   'Lng': -51.995,
#   'Max Temp': 88.25,
#   'Humidity': 49,
#   'Cloudiness': 2,
#   'Wind Speed': 4.25,
#   'Country': 'BR',
#   'Date': '2021-06-05 14:00:43',
#   'Current Description': 'clear sky'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 32.81,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 10.36,
#   'Country': 'CA',
#   'Date': '2021-06-05 14:03:51',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sarangani',
#   'Lat': 5.4033,
#   'Lng': 125.4636,
#   'Max Temp': 83.57,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 7.65,
#   'Country': 'PH',
#   'Date': '2021-06-05 14:03:51',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Camacha',
#   'Lat': 33.0833,
#   'Lng': -16.3333,
#   'Max Temp': 69.53,
#   'Humidity': 60,
#   'Cloudiness': 40,
#   'Wind Speed': 14.97,
#   'Country': 'PT',
#   'Date': '2021-06-05 14:03:52',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ampanihy',
#   'Lat': -24.7,
#   'Lng': 44.75,
#   'Max Temp': 66.63,
#   'Humidity': 76,
#   'Cloudiness': 84,
#   'Wind Speed': 12.71,
#   'Country': 'MG',
#   'Date': '2021-06-05 14:03:52',
#   'Current Description': 'light rain'},
#  {'City': 'Isangel',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 74.59,
#   'Humidity': 82,
#   'Cloudiness': 65,
#   'Wind Speed': 6.29,
#   'Country': 'VU',
#   'Date': '2021-06-05 14:03:52',
#   'Current Description': 'broken clouds'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 74.26,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Country': 'ZA',
#   'Date': '2021-06-05 14:00:00',
#   'Current Description': 'clear sky'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 84.33,
#   'Humidity': 68,
#   'Cloudiness': 76,
#   'Wind Speed': 1.01,
#   'Country': 'HK',
#   'Date': '2021-06-05 14:01:45',
#   'Current Description': 'broken clouds'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 72.12,
#   'Humidity': 51,
#   'Cloudiness': 98,
#   'Wind Speed': 8.03,
#   'Country': 'AU',
#   'Date': '2021-06-05 14:03:53',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Asau',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 72.52,
#   'Humidity': 37,
#   'Cloudiness': 79,
#   'Wind Speed': 4.72,
#   'Country': 'RO',
#   'Date': '2021-06-05 14:03:54',
#   'Current Description': 'broken clouds'},
#  {'City': 'Pokhara',
#   'Lat': 28.2333,
#   'Lng': 83.9833,
#   'Max Temp': 78.26,
#   'Humidity': 58,
#   'Cloudiness': 66,
#   'Wind Speed': 3.85,
#   'Country': 'NP',
#   'Date': '2021-06-05 14:00:11',
#   'Current Description': 'broken clouds'},
#  {'City': 'Fortuna',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 52.2,
#   'Humidity': 61,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Date': '2021-06-05 14:01:36',
#   'Current Description': 'clear sky'},
#  {'City': 'Katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 72.1,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 10.31,
#   'Country': 'JP',
#   'Date': '2021-06-05 14:03:54',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nelson',
#   'Lat': -41.2833,
#   'Lng': 173.2833,
#   'Max Temp': 58.28,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'NZ',
#   'Date': '2021-06-05 14:00:33',
#   'Current Description': 'moderate rain'},
#  {'City': 'Krasnoye',
#   'Lat': 49.9145,
#   'Lng': 24.6134,
#   'Max Temp': 67.35,
#   'Humidity': 69,
#   'Cloudiness': 99,
#   'Wind Speed': 5.32,
#   'Country': 'UA',
#   'Date': '2021-06-05 14:03:55',
#   'Current Description': 'moderate rain'},
#  {'City': 'Nyurba',
#   'Lat': 63.2842,
#   'Lng': 118.3319,
#   'Max Temp': 48.2,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 1.9,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:03:55',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Xingyi',
#   'Lat': 24.1877,
#   'Lng': 102.817,
#   'Max Temp': 64.98,
#   'Humidity': 87,
#   'Cloudiness': 34,
#   'Wind Speed': 2.8,
#   'Country': 'CN',
#   'Date': '2021-06-05 14:03:56',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bonavista',
#   'Lat': 48.6499,
#   'Lng': -53.1147,
#   'Max Temp': 45.82,
#   'Humidity': 82,
#   'Cloudiness': 98,
#   'Wind Speed': 3.91,
#   'Country': 'CA',
#   'Date': '2021-06-05 14:03:56',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 78.66,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Country': 'BR',
#   'Date': '2021-06-05 13:59:03',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Puerto Madero',
#   'Lat': 14.7208,
#   'Lng': -92.4215,
#   'Max Temp': 80.17,
#   'Humidity': 77,
#   'Cloudiness': 99,
#   'Wind Speed': 3.36,
#   'Country': 'MX',
#   'Date': '2021-06-05 14:03:56',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Itoman',
#   'Lat': 26.1247,
#   'Lng': 127.6694,
#   'Max Temp': 81.37,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Country': 'JP',
#   'Date': '2021-06-05 14:03:57',
#   'Current Description': 'broken clouds'},
#  {'City': 'Tazovskiy',
#   'Lat': 67.4667,
#   'Lng': 78.7,
#   'Max Temp': 33.71,
#   'Humidity': 78,
#   'Cloudiness': 91,
#   'Wind Speed': 18.97,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:03:57',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 64.63,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 13.94,
#   'Country': 'ZA',
#   'Date': '2021-06-05 14:03:58',
#   'Current Description': 'clear sky'},
#  {'City': 'Airai',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 58.19,
#   'Humidity': 93,
#   'Cloudiness': 94,
#   'Wind Speed': 3.22,
#   'Country': 'TL',
#   'Date': '2021-06-05 14:03:58',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Grand Gaube',
#   'Lat': -20.0064,
#   'Lng': 57.6608,
#   'Max Temp': 75.38,
#   'Humidity': 79,
#   'Cloudiness': 6,
#   'Wind Speed': 1.99,
#   'Country': 'MU',
#   'Date': '2021-06-05 14:03:58',
#   'Current Description': 'clear sky'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 55.09,
#   'Humidity': 1,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'AR',
#   'Date': '2021-06-05 14:03:59',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 49.8,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 13.33,
#   'Country': 'NZ',
#   'Date': '2021-06-05 14:01:09',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pisco',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 61.02,
#   'Humidity': 88,
#   'Cloudiness': 44,
#   'Wind Speed': 2.73,
#   'Country': 'PE',
#   'Date': '2021-06-05 14:03:59',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tateyama',
#   'Lat': 34.9833,
#   'Lng': 139.8667,
#   'Max Temp': 72.01,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 11.3,
#   'Country': 'JP',
#   'Date': '2021-06-05 14:03:59',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Salalah',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 84.56,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 11.99,
#   'Country': 'OM',
#   'Date': '2021-06-05 14:04:00',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ust-Kuyga',
#   'Lat': 70.0167,
#   'Lng': 135.6,
#   'Max Temp': 38.57,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 7.67,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:04:00',
#   'Current Description': 'moderate rain'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 49.96,
#   'Humidity': 76,
#   'Cloudiness': 62,
#   'Wind Speed': 8.3,
#   'Country': 'CL',
#   'Date': '2021-06-05 14:04:01',
#   'Current Description': 'broken clouds'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 64.38,
#   'Humidity': 68,
#   'Cloudiness': 18,
#   'Wind Speed': 8.5,
#   'Country': 'ZA',
#   'Date': '2021-06-05 14:04:01',
#   'Current Description': 'few clouds'},
#  {'City': 'San Cristobal',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 76.37,
#   'Humidity': 67,
#   'Cloudiness': 95,
#   'Wind Speed': 5.79,
#   'Country': 'VE',
#   'Date': '2021-06-05 14:04:02',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chumikan',
#   'Lat': 54.7183,
#   'Lng': 135.315,
#   'Max Temp': 34.18,
#   'Humidity': 98,
#   'Cloudiness': 91,
#   'Wind Speed': 5.17,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:04:02',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 73.45,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'CK',
#   'Date': '2021-06-05 14:04:03',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kilingi-Nomme',
#   'Lat': 58.1503,
#   'Lng': 24.9642,
#   'Max Temp': 70.65,
#   'Humidity': 49,
#   'Cloudiness': 64,
#   'Wind Speed': 8.61,
#   'Country': 'EE',
#   'Date': '2021-06-05 14:04:03',
#   'Current Description': 'broken clouds'},
#  {'City': 'Shakhovskaya',
#   'Lat': 56.0283,
#   'Lng': 35.5097,
#   'Max Temp': 69.26,
#   'Humidity': 54,
#   'Cloudiness': 4,
#   'Wind Speed': 8.05,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:04:03',
#   'Current Description': 'clear sky'},
#  {'City': 'Guilin',
#   'Lat': 25.2819,
#   'Lng': 110.2864,
#   'Max Temp': 71.31,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 1.59,
#   'Country': 'CN',
#   'Date': '2021-06-05 14:04:04',
#   'Current Description': 'clear sky'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': 51.87,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 10.83,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:04:04',
#   'Current Description': 'light rain'},
#  {'City': 'Faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 80.65,
#   'Humidity': 74,
#   'Cloudiness': 98,
#   'Wind Speed': 5.86,
#   'Country': 'PF',
#   'Date': '2021-06-05 14:04:05',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ballina',
#   'Lat': -28.8667,
#   'Lng': 153.5667,
#   'Max Temp': 50.95,
#   'Humidity': 91,
#   'Cloudiness': 10,
#   'Wind Speed': 6.73,
#   'Country': 'AU',
#   'Date': '2021-06-05 14:04:05',
#   'Current Description': 'clear sky'},
#  {'City': 'Kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 67.71,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'ZA',
#   'Date': '2021-06-05 14:04:05',
#   'Current Description': 'clear sky'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 68.4,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Country': 'PT',
#   'Date': '2021-06-05 14:04:06',
#   'Current Description': 'few clouds'},
#  {'City': 'Silleda',
#   'Lat': 42.696,
#   'Lng': -8.2465,
#   'Max Temp': 77.49,
#   'Humidity': 38,
#   'Cloudiness': 10,
#   'Wind Speed': 5.23,
#   'Country': 'ES',
#   'Date': '2021-06-05 14:04:06',
#   'Current Description': 'clear sky'},
#  {'City': 'Iquitos',
#   'Lat': -3.7481,
#   'Lng': -73.2472,
#   'Max Temp': 81.07,
#   'Humidity': 78,
#   'Cloudiness': 59,
#   'Wind Speed': 2.3,
#   'Country': 'PE',
#   'Date': '2021-06-05 14:04:07',
#   'Current Description': 'broken clouds'},
#  {'City': 'Emirdag',
#   'Lat': 39.0197,
#   'Lng': 31.15,
#   'Max Temp': 64.69,
#   'Humidity': 30,
#   'Cloudiness': 7,
#   'Wind Speed': 8.05,
#   'Country': 'TR',
#   'Date': '2021-06-05 14:04:07',
#   'Current Description': 'clear sky'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 75.16,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 11.36,
#   'Country': 'PF',
#   'Date': '2021-06-05 14:04:07',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 78.48,
#   'Humidity': 75,
#   'Cloudiness': 91,
#   'Wind Speed': 11.74,
#   'Country': 'PF',
#   'Date': '2021-06-05 14:04:08',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Siteki',
#   'Lat': -26.45,
#   'Lng': 31.95,
#   'Max Temp': 60.24,
#   'Humidity': 53,
#   'Cloudiness': 86,
#   'Wind Speed': 4.07,
#   'Country': 'SZ',
#   'Date': '2021-06-05 14:04:08',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kristiansund',
#   'Lat': 63.1115,
#   'Lng': 7.732,
#   'Max Temp': 71.65,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'NO',
#   'Date': '2021-06-05 14:04:09',
#   'Current Description': 'clear sky'},
#  {'City': 'Waingapu',
#   'Lat': -9.6567,
#   'Lng': 120.2641,
#   'Max Temp': 76.59,
#   'Humidity': 83,
#   'Cloudiness': 55,
#   'Wind Speed': 6.69,
#   'Country': 'ID',
#   'Date': '2021-06-05 14:04:09',
#   'Current Description': 'broken clouds'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 79.3,
#   'Humidity': 50,
#   'Cloudiness': 1,
#   'Wind Speed': 13.8,
#   'Country': 'US',
#   'Date': '2021-06-05 14:04:09',
#   'Current Description': 'clear sky'},
#  {'City': 'Honiara',
#   'Lat': -9.4333,
#   'Lng': 159.95,
#   'Max Temp': 77.83,
#   'Humidity': 84,
#   'Cloudiness': 82,
#   'Wind Speed': 3.02,
#   'Country': 'SB',
#   'Date': '2021-06-05 14:04:10',
#   'Current Description': 'broken clouds'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 34.95,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:04:10',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Poum',
#   'Lat': -20.2333,
#   'Lng': 164.0167,
#   'Max Temp': 73.76,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 11.95,
#   'Country': 'NC',
#   'Date': '2021-06-05 14:04:11',
#   'Current Description': 'light rain'},
#  {'City': 'Tarnos',
#   'Lat': 43.5417,
#   'Lng': -1.4628,
#   'Max Temp': 81.14,
#   'Humidity': 68,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Country': 'FR',
#   'Date': '2021-06-05 14:04:11',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gat',
#   'Lat': 31.61,
#   'Lng': 34.7642,
#   'Max Temp': 82.4,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 13.62,
#   'Country': 'IL',
#   'Date': '2021-06-05 14:04:11',
#   'Current Description': 'clear sky'},
#  {'City': 'Pushkino',
#   'Lat': 56.0172,
#   'Lng': 37.8667,
#   'Max Temp': 70.21,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 8.14,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:04:12',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Clyde River',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 32.83,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 7.67,
#   'Country': 'CA',
#   'Date': '2021-06-05 14:04:12',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sao Pedro Do Sul',
#   'Lat': -29.6206,
#   'Lng': -54.1789,
#   'Max Temp': 76.21,
#   'Humidity': 58,
#   'Cloudiness': 44,
#   'Wind Speed': 16.98,
#   'Country': 'BR',
#   'Date': '2021-06-05 14:04:12',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ugoofaaru',
#   'Lat': 5.6667,
#   'Lng': 73,
#   'Max Temp': 82.74,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 17.43,
#   'Country': 'MV',
#   'Date': '2021-06-05 14:04:13',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Usinsk',
#   'Lat': 65.9939,
#   'Lng': 57.5281,
#   'Max Temp': 60.64,
#   'Humidity': 53,
#   'Cloudiness': 100,
#   'Wind Speed': 7.31,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:04:13',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Conde',
#   'Lat': -7.2597,
#   'Lng': -34.9075,
#   'Max Temp': 81.81,
#   'Humidity': 68,
#   'Cloudiness': 29,
#   'Wind Speed': 12.95,
#   'Country': 'BR',
#   'Date': '2021-06-05 14:01:15',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 64.17,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 4.74,
#   'Country': 'UY',
#   'Date': '2021-06-05 14:04:14',
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Plettenberg Bay',
#   'Lat': -34.0527,
#   'Lng': 23.3716,
#   'Max Temp': 66.74,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 7.81,
#   'Country': 'ZA',
#   'Date': '2021-06-05 14:04:14',
#   'Current Description': 'clear sky'},
#  {'City': 'Taoudenni',
#   'Lat': 22.6783,
#   'Lng': -3.9836,
#   'Max Temp': 117.01,
#   'Humidity': 4,
#   'Cloudiness': 10,
#   'Wind Speed': 8.28,
#   'Country': 'ML',
#   'Date': '2021-06-05 14:04:14',
#   'Current Description': 'clear sky'},
#  {'City': 'Shenzhen',
#   'Lat': 22.5455,
#   'Lng': 114.0683,
#   'Max Temp': 84.22,
#   'Humidity': 75,
#   'Cloudiness': 60,
#   'Wind Speed': 4.9,
#   'Country': 'CN',
#   'Date': '2021-06-05 13:59:41',
#   'Current Description': 'broken clouds'},
#  {'City': 'Dubna',
#   'Lat': 56.7333,
#   'Lng': 37.1667,
#   'Max Temp': 71.89,
#   'Humidity': 43,
#   'Cloudiness': 23,
#   'Wind Speed': 8.48,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:00:11',
#   'Current Description': 'few clouds'},
#  {'City': 'Ahualulco',
#   'Lat': 22.4,
#   'Lng': -101.1667,
#   'Max Temp': 57.02,
#   'Humidity': 63,
#   'Cloudiness': 60,
#   'Wind Speed': 0.47,
#   'Country': 'MX',
#   'Date': '2021-06-05 14:04:15',
#   'Current Description': 'broken clouds'},
#  {'City': 'Andenes',
#   'Lat': 69.3143,
#   'Lng': 16.1194,
#   'Max Temp': 51.08,
#   'Humidity': 81,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Country': 'NO',
#   'Date': '2021-06-05 14:04:16',
#   'Current Description': 'few clouds'},
#  {'City': 'Ossora',
#   'Lat': 59.2353,
#   'Lng': 163.0719,
#   'Max Temp': 44.15,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 1.23,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:04:16',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 72.19,
#   'Humidity': 74,
#   'Cloudiness': 91,
#   'Wind Speed': 13.89,
#   'Country': 'US',
#   'Date': '2021-06-05 14:04:16',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Flinders',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 53.26,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Country': 'AU',
#   'Date': '2021-06-05 14:04:17',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chapais',
#   'Lat': 49.7834,
#   'Lng': -74.8492,
#   'Max Temp': 60.58,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 9.6,
#   'Country': 'CA',
#   'Date': '2021-06-05 14:02:48',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Te Anau',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 39.81,
#   'Humidity': 91,
#   'Cloudiness': 23,
#   'Wind Speed': 1.92,
#   'Country': 'NZ',
#   'Date': '2021-06-05 14:04:17',
#   'Current Description': 'few clouds'},
#  {'City': 'Tautira',
#   'Lat': -17.7333,
#   'Lng': -149.15,
#   'Max Temp': 78.82,
#   'Humidity': 76,
#   'Cloudiness': 85,
#   'Wind Speed': 9.84,
#   'Country': 'PF',
#   'Date': '2021-06-05 14:04:17',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 39.36,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 1.48,
#   'Country': 'GL',
#   'Date': '2021-06-05 14:04:18',
#   'Current Description': 'light rain'},
#  {'City': 'Nara',
#   'Lat': 34.6851,
#   'Lng': 135.8049,
#   'Max Temp': 69.08,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 1.28,
#   'Country': 'JP',
#   'Date': '2021-06-05 14:04:18',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ruthin',
#   'Lat': 53.1137,
#   'Lng': -3.3178,
#   'Max Temp': 72.97,
#   'Humidity': 68,
#   'Cloudiness': 86,
#   'Wind Speed': 5.01,
#   'Country': 'GB',
#   'Date': '2021-06-05 14:04:18',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Juneau',
#   'Lat': 58.3019,
#   'Lng': -134.4197,
#   'Max Temp': 48.22,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 2.28,
#   'Country': 'US',
#   'Date': '2021-06-05 14:00:14',
#   'Current Description': 'light rain'},
#  {'City': 'Dwarka',
#   'Lat': 22.2394,
#   'Lng': 68.9678,
#   'Max Temp': 85.87,
#   'Humidity': 68,
#   'Cloudiness': 2,
#   'Wind Speed': 15.23,
#   'Country': 'IN',
#   'Date': '2021-06-05 14:04:19',
#   'Current Description': 'clear sky'},
#  {'City': 'Port Hardy',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 49.55,
#   'Humidity': 86,
#   'Cloudiness': 95,
#   'Wind Speed': 8.28,
#   'Country': 'CA',
#   'Date': '2021-06-05 14:04:19',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sanandrei',
#   'Lat': 45.8531,
#   'Lng': 21.1681,
#   'Max Temp': 80.74,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 2.17,
#   'Country': 'RO',
#   'Date': '2021-06-05 14:04:20',
#   'Current Description': 'clear sky'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 76.55,
#   'Humidity': 84,
#   'Cloudiness': 48,
#   'Wind Speed': 5.46,
#   'Country': 'RE',
#   'Date': '2021-06-05 14:04:20',
#   'Current Description': 'light rain'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 47.91,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 3,
#   'Country': 'AU',
#   'Date': '2021-06-05 14:04:20',
#   'Current Description': 'few clouds'},
#  {'City': 'Sorsk',
#   'Lat': 54.0033,
#   'Lng': 90.2467,
#   'Max Temp': 39.72,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 7.25,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:04:21',
#   'Current Description': 'light rain'},
#  {'City': 'Thunder Bay',
#   'Lat': 48.4001,
#   'Lng': -89.3168,
#   'Max Temp': 69.98,
#   'Humidity': 96,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Date': '2021-06-05 13:59:53',
#   'Current Description': 'broken clouds'},
#  {'City': 'Yulara',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 51.73,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 8.12,
#   'Country': 'AU',
#   'Date': '2021-06-05 14:01:17',
#   'Current Description': 'clear sky'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 77.29,
#   'Humidity': 91,
#   'Cloudiness': 48,
#   'Wind Speed': 0.54,
#   'Country': 'US',
#   'Date': '2021-06-05 14:04:22',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 68.29,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 4.03,
#   'Country': 'JP',
#   'Date': '2021-06-05 14:04:22',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Maceio',
#   'Lat': -9.6658,
#   'Lng': -35.7353,
#   'Max Temp': 80.04,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 16.15,
#   'Country': 'BR',
#   'Date': '2021-06-05 14:04:22',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hamilton',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 79.77,
#   'Humidity': 69,
#   'Cloudiness': 1,
#   'Wind Speed': 3.74,
#   'Country': 'US',
#   'Date': '2021-06-05 14:04:23',
#   'Current Description': 'clear sky'},
#  {'City': 'Namibe',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 80.49,
#   'Humidity': 46,
#   'Cloudiness': 2,
#   'Wind Speed': 8.14,
#   'Country': 'AO',
#   'Date': '2021-06-05 14:04:23',
#   'Current Description': 'clear sky'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 34.23,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 0.76,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:04:24',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nuuk',
#   'Lat': 64.1835,
#   'Lng': -51.7216,
#   'Max Temp': 39.81,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'GL',
#   'Date': '2021-06-05 14:02:13',
#   'Current Description': 'light rain'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 74.64,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 5.17,
#   'Country': 'BR',
#   'Date': '2021-06-05 14:04:25',
#   'Current Description': 'clear sky'},
#  {'City': 'Bairiki',
#   'Lat': 1.3292,
#   'Lng': 172.9752,
#   'Max Temp': 81.99,
#   'Humidity': 70,
#   'Cloudiness': 7,
#   'Wind Speed': 5.64,
#   'Country': 'KI',
#   'Date': '2021-06-05 14:04:25',
#   'Current Description': 'clear sky'},
#  {'City': 'Bardsir',
#   'Lat': 29.9227,
#   'Lng': 56.5743,
#   'Max Temp': 92.21,
#   'Humidity': 7,
#   'Cloudiness': 22,
#   'Wind Speed': 12.68,
#   'Country': 'IR',
#   'Date': '2021-06-05 14:04:26',
#   'Current Description': 'few clouds'},
#  {'City': 'Riyadh',
#   'Lat': 24.6877,
#   'Lng': 46.7219,
#   'Max Temp': 110.43,
#   'Humidity': 5,
#   'Cloudiness': 2,
#   'Wind Speed': 8.1,
#   'Country': 'SA',
#   'Date': '2021-06-05 14:03:32',
#   'Current Description': 'clear sky'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 70.63,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 9.64,
#   'Country': 'BR',
#   'Date': '2021-06-05 14:04:26',
#   'Current Description': 'clear sky'},
#  {'City': 'Chernyy Yar',
#   'Lat': 48.0624,
#   'Lng': 46.1091,
#   'Max Temp': 69.28,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 11.12,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:04:27',
#   'Current Description': 'moderate rain'},
#  {'City': 'Egvekinot',
#   'Lat': 66.3167,
#   'Lng': -179.1667,
#   'Max Temp': 32.14,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 2.04,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:04:27',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Santa Cruz De La Palma',
#   'Lat': 28.6835,
#   'Lng': -17.7642,
#   'Max Temp': 73.54,
#   'Humidity': 60,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Country': 'ES',
#   'Date': '2021-06-05 14:04:27',
#   'Current Description': 'few clouds'},
#  {'City': 'Noumea',
#   'Lat': -22.2763,
#   'Lng': 166.4572,
#   'Max Temp': 73.99,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 14.12,
#   'Country': 'NC',
#   'Date': '2021-06-05 14:00:05',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Jacobabad',
#   'Lat': 28.281,
#   'Lng': 68.4388,
#   'Max Temp': 108.28,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 12.28,
#   'Country': 'PK',
#   'Date': '2021-06-05 14:04:28',
#   'Current Description': 'clear sky'},
#  {'City': 'Ostrovnoy',
#   'Lat': 68.0531,
#   'Lng': 39.5131,
#   'Max Temp': 46.26,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 14.61,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:04:28',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Shatrovo',
#   'Lat': 56.5167,
#   'Lng': 64.6333,
#   'Max Temp': 67.69,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 7.74,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:04:29',
#   'Current Description': 'clear sky'},
#  {'City': 'Sandnessjoen',
#   'Lat': 66.0217,
#   'Lng': 12.6316,
#   'Max Temp': 74.57,
#   'Humidity': 88,
#   'Cloudiness': 3,
#   'Wind Speed': 3.24,
#   'Country': 'NO',
#   'Date': '2021-06-05 14:04:29',
#   'Current Description': 'clear sky'},
#  {'City': 'Camaqua',
#   'Lat': -30.8511,
#   'Lng': -51.8122,
#   'Max Temp': 80.51,
#   'Humidity': 52,
#   'Cloudiness': 21,
#   'Wind Speed': 9.69,
#   'Country': 'BR',
#   'Date': '2021-06-05 14:01:09',
#   'Current Description': 'few clouds'},
#  {'City': 'Grande Riviere Du Nord',
#   'Lat': 19.5833,
#   'Lng': -72.1833,
#   'Max Temp': 80.65,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 3.15,
#   'Country': 'HT',
#   'Date': '2021-06-05 14:04:30',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mezen',
#   'Lat': 65.8522,
#   'Lng': 44.24,
#   'Max Temp': 63.86,
#   'Humidity': 50,
#   'Cloudiness': 18,
#   'Wind Speed': 11.86,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:04:30',
#   'Current Description': 'few clouds'},
#  {'City': 'Yar-Sale',
#   'Lat': 66.8333,
#   'Lng': 70.8333,
#   'Max Temp': 46.13,
#   'Humidity': 55,
#   'Cloudiness': 96,
#   'Wind Speed': 18.19,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:04:30',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Upington',
#   'Lat': -28.4478,
#   'Lng': 21.2561,
#   'Max Temp': 69.85,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 11.9,
#   'Country': 'ZA',
#   'Date': '2021-06-05 14:04:31',
#   'Current Description': 'clear sky'},
#  {'City': 'Nouadhibou',
#   'Lat': 20.931,
#   'Lng': -17.0347,
#   'Max Temp': 69.58,
#   'Humidity': 69,
#   'Cloudiness': 55,
#   'Wind Speed': 21.18,
#   'Country': 'MR',
#   'Date': '2021-06-05 14:04:31',
#   'Current Description': 'broken clouds'},
#  {'City': 'Khasan',
#   'Lat': 42.4308,
#   'Lng': 130.6434,
#   'Max Temp': 54.59,
#   'Humidity': 89,
#   'Cloudiness': 84,
#   'Wind Speed': 6.06,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:04:32',
#   'Current Description': 'light rain'},
#  {'City': 'Baglung',
#   'Lat': 28.2719,
#   'Lng': 83.5898,
#   'Max Temp': 75.15,
#   'Humidity': 63,
#   'Cloudiness': 97,
#   'Wind Speed': 3.67,
#   'Country': 'NP',
#   'Date': '2021-06-05 14:04:32',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vestmannaeyjar',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp': 47.71,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 26.75,
#   'Country': 'IS',
#   'Date': '2021-06-05 14:04:32',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vana-Vigala',
#   'Lat': 58.7806,
#   'Lng': 24.2522,
#   'Max Temp': 71.64,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 5.32,
#   'Country': 'EE',
#   'Date': '2021-06-05 14:04:33',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kalmunai',
#   'Lat': 7.4167,
#   'Lng': 81.8167,
#   'Max Temp': 82.9,
#   'Humidity': 72,
#   'Cloudiness': 84,
#   'Wind Speed': 5.68,
#   'Country': 'LK',
#   'Date': '2021-06-05 14:04:33',
#   'Current Description': 'broken clouds'},
#  {'City': 'Sovetskaya Gavan',
#   'Lat': 48.9723,
#   'Lng': 140.2878,
#   'Max Temp': 45.52,
#   'Humidity': 85,
#   'Cloudiness': 96,
#   'Wind Speed': 4.21,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:04:34',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Meulaboh',
#   'Lat': 4.1363,
#   'Lng': 96.1285,
#   'Max Temp': 78.49,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 4.38,
#   'Country': 'ID',
#   'Date': '2021-06-05 14:04:34',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tura',
#   'Lat': 25.5198,
#   'Lng': 90.2201,
#   'Max Temp': 76.39,
#   'Humidity': 91,
#   'Cloudiness': 81,
#   'Wind Speed': 6.15,
#   'Country': 'IN',
#   'Date': '2021-06-05 14:04:34',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kamenka',
#   'Lat': 51.3223,
#   'Lng': 42.7678,
#   'Max Temp': 55.26,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 13.2,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:04:35',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Krasnozerskoye',
#   'Lat': 53.9828,
#   'Lng': 79.2374,
#   'Max Temp': 54.5,
#   'Humidity': 69,
#   'Cloudiness': 58,
#   'Wind Speed': 5.88,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:04:35',
#   'Current Description': 'broken clouds'},
#  {'City': 'Lieksa',
#   'Lat': 63.3167,
#   'Lng': 30.0167,
#   'Max Temp': 70.41,
#   'Humidity': 39,
#   'Cloudiness': 30,
#   'Wind Speed': 4.25,
#   'Country': 'FI',
#   'Date': '2021-06-05 14:04:36',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Waddan',
#   'Lat': 29.1614,
#   'Lng': 16.139,
#   'Max Temp': 92.03,
#   'Humidity': 11,
#   'Cloudiness': 1,
#   'Wind Speed': 13.76,
#   'Country': 'LY',
#   'Date': '2021-06-05 14:04:36',
#   'Current Description': 'clear sky'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 52.57,
#   'Humidity': 93,
#   'Cloudiness': 94,
#   'Wind Speed': 4.36,
#   'Country': 'AU',
#   'Date': '2021-06-05 14:02:58',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 82.56,
#   'Humidity': 68,
#   'Cloudiness': 90,
#   'Wind Speed': 4.52,
#   'Country': 'KI',
#   'Date': '2021-06-05 14:04:36',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Imbituba',
#   'Lat': -28.24,
#   'Lng': -48.6703,
#   'Max Temp': 76.62,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 11.68,
#   'Country': 'BR',
#   'Date': '2021-06-05 14:02:34',
#   'Current Description': 'clear sky'},
#  {'City': 'Paray-Le-Monial',
#   'Lat': 46.4546,
#   'Lng': 4.1158,
#   'Max Temp': 63.68,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 1.99,
#   'Country': 'FR',
#   'Date': '2021-06-05 14:04:37',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 58.1,
#   'Humidity': 57,
#   'Cloudiness': 99,
#   'Wind Speed': 11.72,
#   'Country': 'AU',
#   'Date': '2021-06-05 14:04:38',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Padang',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 76.32,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 4.74,
#   'Country': 'ID',
# ...
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 13.6,
#   'Country': 'TM',
#   'Date': '2021-06-05 14:07:17',
#   'Current Description': 'clear sky'},
#  {'City': 'Atambua',
#   'Lat': -9.1061,
#   'Lng': 124.8925,
#   'Max Temp': 71.69,
#   'Humidity': 89,
#   'Cloudiness': 62,
#   'Wind Speed': 5.41,
#   'Country': 'ID',
#   'Date': '2021-06-05 14:07:17',
#   'Current Description': 'broken clouds'},
#  {'City': 'Salinopolis',
#   'Lat': -0.6136,
#   'Lng': -47.3561,
#   'Max Temp': 85.53,
#   'Humidity': 65,
#   'Cloudiness': 6,
#   'Wind Speed': 11.34,
#   'Country': 'BR',
#   'Date': '2021-06-05 14:07:18',
#   'Current Description': 'clear sky'},
#  {'City': 'Koslan',
#   'Lat': 63.4564,
#   'Lng': 48.8989,
#   'Max Temp': 79.52,
#   'Humidity': 26,
#   'Cloudiness': 13,
#   'Wind Speed': 8.81,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:07:18',
#   'Current Description': 'few clouds'},
#  {'City': 'Zlitan',
#   'Lat': 32.4674,
#   'Lng': 14.5687,
#   'Max Temp': 79.18,
#   'Humidity': 42,
#   'Cloudiness': 82,
#   'Wind Speed': 16.35,
#   'Country': 'LY',
#   'Date': '2021-06-05 14:07:18',
#   'Current Description': 'broken clouds'},
#  {'City': 'Saint-Georges',
#   'Lat': 12.0564,
#   'Lng': -61.7485,
#   'Max Temp': 76.68,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'GD',
#   'Date': '2021-06-05 14:07:19',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kabare',
#   'Lat': -2.4683,
#   'Lng': 28.8242,
#   'Max Temp': 69.46,
#   'Humidity': 81,
#   'Cloudiness': 73,
#   'Wind Speed': 4.83,
#   'Country': 'CD',
#   'Date': '2021-06-05 14:07:19',
#   'Current Description': 'light rain'},
#  {'City': 'Zlobin',
#   'Lat': 45.2924,
#   'Lng': 14.6541,
#   'Max Temp': 72.7,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 5.46,
#   'Country': 'HR',
#   'Date': '2021-06-05 14:07:19',
#   'Current Description': 'clear sky'},
#  {'City': 'Santa Marinella',
#   'Lat': 42.0345,
#   'Lng': 11.8536,
#   'Max Temp': 78.91,
#   'Humidity': 78,
#   'Cloudiness': 96,
#   'Wind Speed': 5.86,
#   'Country': 'IT',
#   'Date': '2021-06-05 14:07:20',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tigil',
#   'Lat': 57.8,
#   'Lng': 158.6667,
#   'Max Temp': 48.79,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 8.01,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:07:20',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kieta',
#   'Lat': -6.2167,
#   'Lng': 155.6333,
#   'Max Temp': 78.6,
#   'Humidity': 84,
#   'Cloudiness': 19,
#   'Wind Speed': 5.12,
#   'Country': 'PG',
#   'Date': '2021-06-05 14:07:20',
#   'Current Description': 'few clouds'},
#  {'City': 'Batesville',
#   'Lat': 35.7698,
#   'Lng': -91.641,
#   'Max Temp': 75.61,
#   'Humidity': 84,
#   'Cloudiness': 40,
#   'Wind Speed': 3.47,
#   'Country': 'US',
#   'Date': '2021-06-05 14:07:21',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ajdabiya',
#   'Lat': 30.7554,
#   'Lng': 20.2263,
#   'Max Temp': 82.04,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 18.84,
#   'Country': 'LY',
#   'Date': '2021-06-05 14:07:21',
#   'Current Description': 'clear sky'},
#  {'City': 'Port-Gentil',
#   'Lat': -0.7193,
#   'Lng': 8.7815,
#   'Max Temp': 79.48,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 12.53,
#   'Country': 'GA',
#   'Date': '2021-06-05 14:07:21',
#   'Current Description': 'light rain'},
#  {'City': 'Goure',
#   'Lat': 13.9835,
#   'Lng': 10.2704,
#   'Max Temp': 100.02,
#   'Humidity': 15,
#   'Cloudiness': 100,
#   'Wind Speed': 5.93,
#   'Country': 'NE',
#   'Date': '2021-06-05 14:07:22',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nichinan',
#   'Lat': 31.6,
#   'Lng': 131.3667,
#   'Max Temp': 61.07,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 6.71,
#   'Country': 'JP',
#   'Date': '2021-06-05 14:07:22',
#   'Current Description': 'light rain'},
#  {'City': 'Thinadhoo',
#   'Lat': 0.5333,
#   'Lng': 72.9333,
#   'Max Temp': 83.62,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 16.8,
#   'Country': 'MV',
#   'Date': '2021-06-05 14:05:15',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Zhukovka',
#   'Lat': 53.534,
#   'Lng': 33.728,
#   'Max Temp': 64.67,
#   'Humidity': 64,
#   'Cloudiness': 66,
#   'Wind Speed': 8.57,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:07:23',
#   'Current Description': 'light rain'},
#  {'City': 'Palmer',
#   'Lat': 42.1584,
#   'Lng': -72.3287,
#   'Max Temp': 81.95,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2021-06-05 14:07:23',
#   'Current Description': 'few clouds'},
#  {'City': 'Akcaabat',
#   'Lat': 41.0212,
#   'Lng': 39.5715,
#   'Max Temp': 64.27,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 0.96,
#   'Country': 'TR',
#   'Date': '2021-06-05 14:07:23',
#   'Current Description': 'broken clouds'},
#  {'City': 'Batemans Bay',
#   'Lat': -35.7167,
#   'Lng': 150.1833,
#   'Max Temp': 47.91,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 4.94,
#   'Country': 'AU',
#   'Date': '2021-06-05 14:07:24',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cacule',
#   'Lat': -14.5033,
#   'Lng': -42.2222,
#   'Max Temp': 81.97,
#   'Humidity': 40,
#   'Cloudiness': 53,
#   'Wind Speed': 11.95,
#   'Country': 'BR',
#   'Date': '2021-06-05 14:07:24',
#   'Current Description': 'broken clouds'},
#  {'City': 'Axim',
#   'Lat': 4.8699,
#   'Lng': -2.2405,
#   'Max Temp': 85.23,
#   'Humidity': 64,
#   'Cloudiness': 73,
#   'Wind Speed': 8.52,
#   'Country': 'GH',
#   'Date': '2021-06-05 14:07:24',
#   'Current Description': 'light rain'},
#  {'City': 'Banda Aceh',
#   'Lat': 5.5577,
#   'Lng': 95.3222,
#   'Max Temp': 80.51,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 10.85,
#   'Country': 'ID',
#   'Date': '2021-06-05 14:03:36',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bouca',
#   'Lat': 6.5105,
#   'Lng': 18.2733,
#   'Max Temp': 85.86,
#   'Humidity': 54,
#   'Cloudiness': 65,
#   'Wind Speed': 1.59,
#   'Country': 'CF',
#   'Date': '2021-06-05 14:07:25',
#   'Current Description': 'light rain'},
#  {'City': 'Mantua',
#   'Lat': 45.1667,
#   'Lng': 10.7833,
#   'Max Temp': 88.09,
#   'Humidity': 47,
#   'Cloudiness': 26,
#   'Wind Speed': 5.99,
#   'Country': 'IT',
#   'Date': '2021-06-05 14:07:25',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kuching',
#   'Lat': 1.55,
#   'Lng': 110.3333,
#   'Max Temp': 79.02,
#   'Humidity': 89,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Country': 'MY',
#   'Date': '2021-06-05 14:07:26',
#   'Current Description': 'few clouds'},
#  {'City': 'Uvira',
#   'Lat': -3.4067,
#   'Lng': 29.1458,
#   'Max Temp': 80.38,
#   'Humidity': 67,
#   'Cloudiness': 55,
#   'Wind Speed': 7.02,
#   'Country': 'CD',
#   'Date': '2021-06-05 14:07:26',
#   'Current Description': 'light rain'},
#  {'City': 'Dhidhdhoo',
#   'Lat': 6.8833,
#   'Lng': 73.1,
#   'Max Temp': 82.94,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 15.12,
#   'Country': 'MV',
#   'Date': '2021-06-05 14:07:26',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kiunga',
#   'Lat': -6.1219,
#   'Lng': 141.2906,
#   'Max Temp': 71.19,
#   'Humidity': 100,
#   'Cloudiness': 95,
#   'Wind Speed': 1.86,
#   'Country': 'PG',
#   'Date': '2021-06-05 14:07:27',
#   'Current Description': 'light rain'},
#  {'City': 'Middlebury',
#   'Lat': 44.0153,
#   'Lng': -73.1673,
#   'Max Temp': 81.1,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 5.01,
#   'Country': 'US',
#   'Date': '2021-06-05 14:07:27',
#   'Current Description': 'broken clouds'},
#  {'City': 'Zhigalovo',
#   'Lat': 54.8097,
#   'Lng': 105.1578,
#   'Max Temp': 66.09,
#   'Humidity': 75,
#   'Cloudiness': 61,
#   'Wind Speed': 4.16,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:07:27',
#   'Current Description': 'broken clouds'},
#  {'City': 'Ketchikan',
#   'Lat': 55.3422,
#   'Lng': -131.6461,
#   'Max Temp': 48.67,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Date': '2021-06-05 14:07:28',
#   'Current Description': 'moderate rain'},
#  {'City': 'Siilinjarvi',
#   'Lat': 63.0833,
#   'Lng': 27.6667,
#   'Max Temp': 77.02,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 4.07,
#   'Country': 'FI',
#   'Date': '2021-06-05 14:07:28',
#   'Current Description': 'clear sky'},
#  {'City': 'Aasiaat',
#   'Lat': 68.7098,
#   'Lng': -52.8699,
#   'Max Temp': 36.81,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 9.33,
#   'Country': 'GL',
#   'Date': '2021-06-05 14:07:28',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Constitucion',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 52.21,
#   'Humidity': 64,
#   'Cloudiness': 24,
#   'Wind Speed': 7.99,
#   'Country': 'CL',
#   'Date': '2021-06-05 14:05:45',
#   'Current Description': 'few clouds'},
#  {'City': 'Wewak',
#   'Lat': -3.5534,
#   'Lng': 143.6268,
#   'Max Temp': 76.53,
#   'Humidity': 90,
#   'Cloudiness': 20,
#   'Wind Speed': 8.59,
#   'Country': 'PG',
#   'Date': '2021-06-05 14:07:29',
#   'Current Description': 'few clouds'},
#  {'City': 'Viisoara',
#   'Lat': 46.55,
#   'Lng': 23.9167,
#   'Max Temp': 74.97,
#   'Humidity': 27,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'RO',
#   'Date': '2021-06-05 14:07:29',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hachinohe',
#   'Lat': 40.5,
#   'Lng': 141.5,
#   'Max Temp': 57.49,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 6.76,
#   'Country': 'JP',
#   'Date': '2021-06-05 14:07:30',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Korla',
#   'Lat': 41.7597,
#   'Lng': 86.1469,
#   'Max Temp': 84.79,
#   'Humidity': 17,
#   'Cloudiness': 59,
#   'Wind Speed': 12.37,
#   'Country': 'CN',
#   'Date': '2021-06-05 14:07:30',
#   'Current Description': 'broken clouds'},
#  {'City': 'Pincher Creek',
#   'Lat': 49.4833,
#   'Lng': -113.952,
#   'Max Temp': 63.28,
#   'Humidity': 31,
#   'Cloudiness': 1,
#   'Wind Speed': 19.57,
#   'Country': 'CA',
#   'Date': '2021-06-05 14:07:30',
#   'Current Description': 'clear sky'},
#  {'City': 'Mugur-Aksy',
#   'Lat': 50.35,
#   'Lng': 90.5,
#   'Max Temp': 37.31,
#   'Humidity': 52,
#   'Cloudiness': 16,
#   'Wind Speed': 14.5,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:07:31',
#   'Current Description': 'few clouds'},
#  {'City': 'Fuxin',
#   'Lat': 42.0156,
#   'Lng': 121.6589,
#   'Max Temp': 64.89,
#   'Humidity': 51,
#   'Cloudiness': 100,
#   'Wind Speed': 0.76,
#   'Country': 'CN',
#   'Date': '2021-06-05 14:07:31',
#   'Current Description': 'light rain'},
#  {'City': 'Yurla',
#   'Lat': 59.3259,
#   'Lng': 54.3223,
#   'Max Temp': 73.27,
#   'Humidity': 40,
#   'Cloudiness': 62,
#   'Wind Speed': 5.59,
#   'Country': 'RU',
#   'Date': '2021-06-05 14:07:31',
#   'Current Description': 'broken clouds'},
#  {'City': 'Tsogni',
#   'Lat': -2.7942,
#   'Lng': 10.0988,
#   'Max Temp': 81.63,
#   'Humidity': 73,
#   'Cloudiness': 74,
#   'Wind Speed': 9.17,
#   'Country': 'GA',
#   'Date': '2021-06-05 14:07:32',
#   'Current Description': 'broken clouds'},
#  {'City': 'Varkaus',
#   'Lat': 62.3153,
#   'Lng': 27.873,
#   'Max Temp': 76.3,
#   'Humidity': 35,
#   'Cloudiness': 99,
#   'Wind Speed': 4.23,
#   'Country': 'FI',
#   'Date': '2021-06-05 14:07:32',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mercedes',
#   'Lat': -34.6515,
#   'Lng': -59.4307,
#   'Max Temp': 56.03,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 12.33,
#   'Country': 'AR',
#   'Date': '2021-06-05 14:07:32',
#   'Current Description': 'overcast clouds'},
#  {'City': 'General Pico',
#   'Lat': -35.6566,
#   'Lng': -63.7568,
#   'Max Temp': 56.62,
#   'Humidity': 48,
#   'Cloudiness': 10,
#   'Wind Speed': 11.9,
#   'Country': 'AR',
#   'Date': '2021-06-05 14:07:33',
#   'Current Description': 'clear sky'},
#  {'City': 'Zaysan',
#   'Lat': 47.4667,
#   'Lng': 84.8667,
#   'Max Temp': 50.95,
#   'Humidity': 57,
#   'Cloudiness': 39,
#   'Wind Speed': 12.84,
#   'Country': 'KZ',
#   'Date': '2021-06-05 14:07:33',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Pontes E Lacerda',
#   'Lat': -15.2261,
#   'Lng': -59.3353,
#   'Max Temp': 86.07,
#   'Humidity': 37,
#   'Cloudiness': 86,
#   'Wind Speed': 4.52,
#   'Country': 'BR',
#   'Date': '2021-06-05 14:07:34',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lisakovsk',
#   'Lat': 52.5369,
#   'Lng': 62.4936,
#   'Max Temp': 67.75,
#   'Humidity': 26,
#   'Cloudiness': 99,
#   'Wind Speed': 7.45,
#   'Country': 'KZ',
#   'Date': '2021-06-05 14:07:34',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nador',
#   'Lat': 35.174,
#   'Lng': -2.9287,
#   'Max Temp': 70.05,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 8.14,
#   'Country': 'MA',
#   'Date': '2021-06-05 14:07:34',
#   'Current Description': 'broken clouds'},
#  {'City': 'Tarakan',
#   'Lat': 3.3,
#   'Lng': 117.6333,
#   'Max Temp': 84.4,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 9.78,
#   'Country': 'ID',
#   'Date': '2021-06-05 14:07:35',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Guinope',
#   'Lat': 13.8833,
#   'Lng': -86.9333,
#   'Max Temp': 71.69,
#   'Humidity': 67,
#   'Cloudiness': 80,
#   'Wind Speed': 4.79,
#   'Country': 'HN',
#   'Date': '2021-06-05 14:07:35',
#   'Current Description': 'broken clouds'},
#  {'City': 'Marmaris',
#   'Lat': 36.855,
#   'Lng': 28.2742,
#   'Max Temp': 84.15,
#   'Humidity': 24,
#   'Cloudiness': 0,
#   'Wind Speed': 15.7,
#   'Country': 'TR',
#   'Date': '2021-06-05 14:07:35',
#   'Current Description': 'clear sky'},
#  {'City': 'Gorom-Gorom',
#   'Lat': 14.4439,
#   'Lng': -0.2361,
#   'Max Temp': 108.05,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 3.83,
#   'Country': 'BF',
#   'Date': '2021-06-05 14:07:36',
#   'Current Description': 'clear sky'},
#  {'City': 'Saint-Louis',
#   'Lat': 16.3333,
#   'Lng': -15,
#   'Max Temp': 111.83,
#   'Humidity': 12,
#   'Cloudiness': 7,
#   'Wind Speed': 10.49,
#   'Country': 'SN',
#   'Date': '2021-06-05 14:07:36',
#   'Current Description': 'clear sky'},
#  {'City': 'Sayyan',
#   'Lat': 15.1718,
#   'Lng': 44.3244,
#   'Max Temp': 77.18,
#   'Humidity': 10,
#   'Cloudiness': 7,
#   'Wind Speed': 20.11,
#   'Country': 'YE',
#   'Date': '2021-06-05 14:07:36',
#   'Current Description': 'clear sky'},
#  {'City': 'Amapa',
#   'Lat': 1,
#   'Lng': -52,
#   'Max Temp': 78.48,
#   'Humidity': 87,
#   'Cloudiness': 98,
#   'Wind Speed': 3.62,
#   'Country': 'BR',
#   'Date': '2021-06-05 14:07:37',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Natal',
#   'Lat': -5.795,
#   'Lng': -35.2094,
#   'Max Temp': 84.85,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 13.67,
#   'Country': 'BR',
#   'Date': '2021-06-05 14:04:07',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Williamsport',
#   'Lat': 41.2412,
#   'Lng': -77.0011,
#   'Max Temp': 81.77,
#   'Humidity': 64,
#   'Cloudiness': 1,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Date': '2021-06-05 14:05:36',
#   'Current Description': 'clear sky'},
#  {'City': 'Mogok',
#   'Lat': 22.9167,
#   'Lng': 96.5,
#   'Max Temp': 68.65,
#   'Humidity': 89,
#   'Cloudiness': 59,
#   'Wind Speed': 2.86,
#   'Country': 'MM',
#   'Date': '2021-06-05 14:07:37',
#   'Current Description': 'broken clouds'},
#  {'City': 'Koumac',
#   'Lat': -20.5667,
#   'Lng': 164.2833,
#   'Max Temp': 71.64,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 5.55,
#   'Country': 'NC',
#   'Date': '2021-06-05 14:07:38',
#   'Current Description': 'light rain'},
#  {'City': 'Kothi',
#   'Lat': 24.75,
#   'Lng': 80.7833,
#   'Max Temp': 95.86,
#   'Humidity': 32,
#   'Cloudiness': 71,
#   'Wind Speed': 13.09,
#   'Country': 'IN',
#   'Date': '2021-06-05 14:07:38',
#   'Current Description': 'broken clouds'},
#  {'City': 'Buraydah',
#   'Lat': 26.326,
#   'Lng': 43.975,
#   'Max Temp': 112.71,
#   'Humidity': 5,
#   'Cloudiness': 9,
#   'Wind Speed': 10.04,
#   'Country': 'SA',
#   'Date': '2021-06-05 14:07:39',
#   'Current Description': 'clear sky'},
#  {'City': 'Kutum',
#   'Lat': 14.2,
#   'Lng': 24.6667,
#   'Max Temp': 94.78,
#   'Humidity': 10,
#   'Cloudiness': 32,
#   'Wind Speed': 16.15,
#   'Country': 'SD',
#   'Date': '2021-06-05 14:07:39',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Lafiagi',
#   'Lat': 8.8667,
#   'Lng': 5.4167,
#   'Max Temp': 94.68,
#   'Humidity': 39,
#   'Cloudiness': 64,
#   'Wind Speed': 7.72,
#   'Country': 'NG',
#   'Date': '2021-06-05 14:07:39',
#   'Current Description': 'broken clouds'},
#  {'City': 'Moron',
#   'Lat': -34.6534,
#   'Lng': -58.6198,
#   'Max Temp': 55.96,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 9.42,
#   'Country': 'AR',
#   'Date': '2021-06-05 14:07:40',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Manzanillo',
#   'Lat': 20.3433,
#   'Lng': -77.1167,
#   'Max Temp': 80.83,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 5.61,
#   'Country': 'CU',
#   'Date': '2021-06-05 14:07:40',
#   'Current Description': 'clear sky'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# Change columns order
# Assign a variable to an array of the columns in the order we want them to appear
column_order = ["City","Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Assign the same DataFrame with new column order
city_data_df = city_data_df[column_order]

# Check data
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0         Busselton      AU -33.6500  115.3333     57.04        74
# 1        Nikolskoye      RU  59.7035   30.7861     78.69        33
# 2        Ongandjera      NA -17.8833   15.0667     76.42        16
# 3           Iqaluit      CA  63.7506  -68.5145     31.69        89
# 4            Mwense      ZM -10.3845   28.6980     77.65        45
# 5       Yellowknife      CA  62.4560 -114.3525     57.33        82
# 6            Albany      US  42.6001  -73.9662     79.75        73
# 7        Georgetown      MY   5.4112  100.3354     80.89        89
# 8         Salisbury      GB  51.0693   -1.7957     72.68        48
# 9  Puerto Escondido      MX  15.8500  -97.0667     83.44        70
#
#    Cloudiness  Wind Speed Current Description
# 0          23       11.65          few clouds
# 1          88        1.19     overcast clouds
# 2           0        9.62           clear sky
# 3          99        8.01     overcast clouds
# 4         100        7.52     overcast clouds
# 5         100        7.83     overcast clouds
# 6           9        8.52           clear sky
# 7          20        2.77       moderate rain
# 8          21        7.43          few clouds
# 9         100        1.50     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
